# %% [markdown]
# # Analysis of portuguese students' habits that influence education

# %% [markdown]
# ***How much should I study if I want to go to the bar?***

# %% [markdown]
# Michael Albarello - michael.albarello@studio.unibo.it - 0001058648
#
# Matteo Nestola - matteo.nestola@studio.unibo.it - 0001036948

# %% [markdown]
# <p id="index"></p>
#
# ## Index
#
# 1. <a href = "#preprocessing"><u>*Preprocessing of the data*</u></a>
#
#     1.1 <a href = "#dropping_columns"><u>*Dropping columns*</u></a>
#
#     1.2 <a href = "#discretizing_age"><u>*Discretizing age*</u></a>
#
#     1.3 <a href = "#discretizing_G3"><u>*Discretizing G3*</u></a>
#
#     1.4 <a href = "#discretizing_absences"><u>*Discretizing absences*</u></a>
#
#     1.5 <a href = "#discretizing_results"><u>*Discretizing results*</u></a>
#
#
#
# 2. <a href = "#data_exploration"><u>*Data Exploration*</u></a>
#
#     2.1 <a href = "#Pstatus_famrel"><u>*Pstatus $\rightarrow$ famrel*</u></a>
#
#     2.2 <a href = "#famrel_famsup"><u>*Famrel $\rightarrow$ famsup*</u></a>
#
#     2.3 <a href = "#famrel_Dalc"><u>*Famrel $\rightarrow$ Dalc*</u></a>
#
#     2.4 <a href = "#Medu/Fedu_famsup"><u>*Medu/Fedu $\rightarrow$ famsup*</u></a>
#
#     2.5 <a href = "#famsup_paid"><u>*Famsup $\rightarrow$ paid*</u></a>
#
#     2.6 <a href = "#paid_G3"><u>*Paid $\rightarrow$ G3*</u></a>
#
#     2.7 <a href = "#freetime_goout"><u>*Freetime $\rightarrow$ goout*</u></a>
#
#     2.8 <a href = "#freetime_activities"><u>*Freetime $\rightarrow$ activities*</u></a>
#
#     2.9 <a href = "#goout_studytime"><u>*Goout $\rightarrow$ studytime*</u></a>
#
#     2.10 <a href = "#activities_studytime"><u>*Activities $\rightarrow$ studytime*</u></a>
#
#     2.11 <a href = "#famsup_studytime"><u>*Famsup $\rightarrow$ studytime*</u></a>
#
#     2.12 <a href = "#Dalc_studytime"><u>*Dalc $\rightarrow$ studytime*</u></a>
#
#     2.13 <a href = "#health_studytime"><u>*Health $\rightarrow$ studytime*</u></a>
#
#     2.14 <a href = "#schoolsup_studytime"><u>*Schoolsup $\rightarrow$ studytime*</u></a>
#
#     2.15 <a href = "#age_G3"><u>*Age $\rightarrow$ G3*</u></a>
#
#     2.16 <a href = "#sex_G3"><u>*Sex $\rightarrow$ G3*</u></a>
#
#     2.17 <a href = "#absences_G3"><u>*Absences $\rightarrow$ G3*</u></a>
#
#     2.18 <a href = "#famsup_G3 "><u>*Famsup $\rightarrow$ G3*</u></a>
#
#     2.19 <a href = "#studytime_G3"><u>*Studytime $\rightarrow$ G3*</u></a>
#
#
# 3. <a href = "#bnia"><u>*Bayesian Network Implementation and Analysis*</u></a>
#
#     3.1 <a href = "#Dalc_block"><u>*Dalc block*</u></a>
#
#     3.2 <a href = "#Famsup_block"><u>*Famsup block*</u></a>
#
#     3.3 <a href = "#Freetime_block"><u>*Freetime block*</u></a>
#
#     3.4 <a href = "#Studytime_block"><u>*Studytime block*</u></a>
#
#     3.5 <a href = "#g3_block"><u>*G3 block*</u></a>
#
#     3.6 <a href = "#resulting_network"><u>*Resulting Network*</u></a>
#
#     3.7 <a href = "#analysis"><u>*Analysis of the resulting network: flow of probabilistic influence*</u></a>
#
#
# 4. <a href = "#parameter_estimation"><u>*Parameter Estimation*</u></a>
#
#
# 5. <a href = "#inferences"><u>*Inferences*</u></a>
#
#     5.1 <a href = "#exact_inferences"><u>*Exact inferences*</u></a>
#
#     5.2 <a href = "#approximate_inferences"><u>*Approximate inferences*</u></a>
#
#
# 6. <a href = "#conclusions"><u>*Conclusions*</u></a>

# %% [markdown]
# In the following notebook, we will analize how students' extracurricular habits are capable to influence their school performance. <br>In particular, we selected the [Student Alcohol Consumption Dataset](https://www.kaggle.com/datasets/uciml/student-alcohol-consumption), which includes grade, demographic, social and school related informations that have been collected by using school reports and questionnaires.
#
# The dataset includes two subsets regarding the students' performances in two distinct subjects:
# - Mathematics (mat)
# - Portuguese Language (por).
#
# Here's some explanation for each column, provided by the dataset's creator:
#
#
# |Columns||Description||Type|
# |:----------||:--------------||:----|
# |**school**||student's school||binary:<br>'GP' - Gabriel Pereira<br>'MS' - Mousinho da Silveira|
# |**sex**||student's sex||binary:<br>'F' - female<br>'M' - male|
# |**age**||student's age||numeric: <br> from 15 to 22|
# |**address**||student's home address type||binary: <br> 'U' - urban <br> 'R' - rural|
# |**famsize**||family size||binary: <br> 'LE3' - less or equal to 3 <br> 'GT3' - greater than 3|
# |**Pstatus**||parent's cohabitation status||binary: <br> 'T' - living together <br> 'A' - apart|
# |**Medu**||mother's education||numeric: <br> 0 - none <br> 1 - primary education (4th grade) <br> 2 - 5th to 9th grade <br> 3 - secondary education <br> 4 - higher education|
# |**Fedu**||father's education||numeric: <br> 0 - none <br> 1 - primary education (4th grade) <br> 2 - 5th to 9th grade <br> 3 - secondary education <br> 4 - higher education|
# |**Mjob**||mother's job||nominal: <br> 'teacher' <br> 'health' care related <br> civil 'services' (e.g. administrative or police) <br> 'at_home' <br> 'other'|
# |**Fjob**||father's job||nominal: <br> 'teacher' <br> 'health' care related <br> civil 'services' (e.g. administrative or police) <br> 'at_home' <br> 'other'|
# |**reason**||reason to choose this school||nominal: <br> close to 'home' <br> school 'reputation' <br> 'course' preference <br> 'other'|
# |**guardian**||student's guardian||nominal: <br> 'mother <br> 'father' <br> 'other'|
# |**traveltime**||home to school travel time||numeric: <br> 1 - <15 min. <br> 2 - 15 to 30 min. <br> 3 - 30 min. to 1 hour <br> or 4 - >1 hour|
# |**studytime**||weekly study time||numeric: <br> 1 - <2 hours <br> 2 - 2 to 5 hours <br> 3 - 5 to 10 hours <br> or 4 - >10 hours|
# |**failures**||number of <u>***past***</u> class failures||numeric: <br> n if 1<=n<3 <br> else 4|
# |**schoolsup**||extra educational support||binary: <br> yes <br> no|
# |**famsup**||family educational support||binary: <br> yes <br> no|
# |**paid**||extra paid classes within the course subject (Math or Portuguese)||binary:<br> yes <br> no|
# |**activities**||extra-curricular activities||binary: <br> yes <br> no|
# |**nursery**||attended nursery school||binary: <br> yes <br> no|
# |**higher**||wants to take higher education||binary: <br> yes <br> no|
# |**internet**||Internet access at home||binary: <br> yes <br> no|
# |**romantic**||with a romantic relationship||binary: <br> yes <br> no|
# |**famrel**||quality of family relationships||numeric: from 1 - very bad <br> to 5 - excellent|
# |**freetime**||free time after school||numeric: <br> from 1 - very low <br> to 5 - very high|
# |**goout**||going out with friends||numeric: <br> from 1 - very low <br> to 5 - very high|
# |**Dalc**||workday alcohol consumption||numeric: <br> from 1 - very low <br> to 5 - very high|
# |**Walc**||weekend alcohol consumption||numeric: <br> from 1 - very low <br> to 5 - very high|
# |**health**||current health status||numeric: <br> from 1 - very bad <br> to 5 - very good|
# |**absences**||number of school absences||numeric: <br> from 0 <br> to 93|
#
#
#
# The following grades are related with the course subject, Math or Portuguese:
#
# |Grade|Description||Type|
# |:------|:--------||:--------|
# |G1|first period grade||numeric: <br>from 0 <br>to 20|
# |G2 |second period grade||numeric: <br>from 0 <br>to 20|
# |G3 |final grade (output target)||numeric: <br>from 0 <br>to 20)|
#
#
# The goal of the following analysis is to obtain a better understanding on how do social environments affect the  curricular career of a generic student.

# %% [markdown]
# ## 0. Imports
# Let's start by importing the needed libraries and datasets:

# %%
import os

#---Data representation---

import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

#---Pgmpy library---

from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
from pgmpy.estimators import ParameterEstimator
from pgmpy.estimators import BayesianEstimator

#---Plot Bayesian Networks---

import networkx as nx

# %%
#paths to datasets:

abs_path = os.getcwd()

mat_path= f'{abs_path}/dataset/student_alcohol/student-mat.csv'
por_path= f'{abs_path}/dataset/student_alcohol/student-por.csv'

#import datasets:
df1 = pd.read_csv(mat_path, sep=",")
df2 = pd.read_csv(por_path, sep=",")

#concatenate subsets:
df = pd.concat([df1, df2])

# %% [markdown]
# Given that the dataset's creator has provided two subsets, the first for students' performance in mathematics and the second in portuguese language, we decided to concatenate both in a single dataframe so that we were able to exploit the totality of the data.
#
# Let's now have a quick look at the data:

# %%
#Dataset's structure info:
print("The imported dataset has the following structure:\n")
print(f"Number of features per individual:\t{len(df.columns)}")
print(f"Number of individuals in the dataset:\t{len(df)}")
print(f"\nColumns names:\n")

for i in range(len(df.columns)):
    print(f"{i}. {df.columns[i]}")

print("\nRepresentation of the first five individuals of the dataset:")
df.head()
# Out:
# The imported dataset has the following structure:
#
# Number of features per individual:	33
# Number of individuals in the dataset:	1044
#
# Columns names:
#
# 0. school
# 1. sex
# 2. age
# 3. address
# 4. famsize
# 5. Pstatus
# 6. Medu
# 7. Fedu
# 8. Mjob
# 9. Fjob
# 10. reason
# 11. guardian
# 12. traveltime
# 13. studytime
# 14. failures
# 15. schoolsup
# 16. famsup
# 17. paid
# 18. activities
# 19. nursery
# 20. higher
# 21. internet
# 22. romantic
# 23. famrel
# 24. freetime
# 25. goout
# 26. Dalc
# 27. Walc
# 28. health
# 29. absences
# 30. G1
# 31. G2
# 32. G3
#
# Representation of the first five individuals of the dataset:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# <p id="preprocessing"></p>
#
# ## 1. Preprocessing

# %% [markdown]
# <p id="dropping_columns"></p>
#
# #### 1.1 Dropping columns

# %% [markdown]
# By looking at the features of the dataset, we have seen that there is a lot of irrelevant and redundant data to drop and continuous data that has to be discretized and denoised.
#
# In particular, the following features will be dropped:
#
# - `school`:  the performance of a student doesn't depend on the choice of the school;
#
#
# - `romantic`: the performance of a student doesn't depend in wheter he has a romantic relationship or not;
#
#
# - `famsize`: the performance of a student doesn't depend whether the family has more or less than three members;
#
#
# - `guardian`: the performance of a student doesn't depend on whom his guardian is;
#
#
# - `nursery`: the performance of a student doesn't depend on whether he attended nursery school or not;
#
#
# - `Walc`: the performance of a student doesn't depend whether he consumes alcohol on weekends;
#
#
# - `traveltime`: which is redundant;
#
#
# - `reason`: the performance of a student doesn't depend on the choice of the school, as we said earlier for the attribute `school`
#
#
# - `Mjob` and `Fjob`: the performance of a student doesn't depend on his parents' job;
#
#
# - `address`: the performance of a student doesn't depend on his home address;
#
#
# - `higher`: the performance of a student doesn't depend whether he wants to attend college or not;
#
#
# - `internet`: the performance of a student doesn't depend on whether he has internet connection at home or not.
#
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
df_new = df.drop(['school',
                  'romantic',   
                  'famsize',
                  'guardian',
                  'nursery',
                  'traveltime',
                  'Walc',
                  'reason',
                  'Mjob',
                  'Fjob',
                  'address',
                  'higher',
                  'internet'],  
                  
                 axis=1)

# %% [markdown]
# Since `G1` and `G2` are intermediate grades, we decided to consider only the final grade `G3`:

# %%
df_new = df_new.drop(['G1','G2',], axis=1)

# %% [markdown]
# <p id="discretizing_age"></p>
#
# #### 1.2 Discretizing age

# %% [markdown]
# Then we decided to discretize the age of the students so that we could divide them in three macrogroups:
#
# - `15-17`: students that have never failed a year;
# - `18-19`: students that have failed one year;
# - `20-22`: students that have failed many years of school.
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
min_age = np.min(df['age'])
max_age = np.max(df['age'])

print(f"The students' minimum age found in the dataset is: {min_age}", end = "")
print(f"\nThe students' maximum age found in the dataset is: {max_age}")


#range 15-17:
num_age15 = len(df[df['age'] == 15])
num_age16 = len(df[df['age'] == 16])
num_age17 = len(df[df['age'] == 17])

print(f"\n\nThere are: \n - {num_age15} students that are 15 years old", end = "")
print(f"\n - {num_age16} students that are 16 years old", end = "")
print(f"\n - {num_age17} students that are 17 years old")
print(f"\nMeaning that the bin '15-17' should comprehend {num_age15 + num_age16 + num_age17} students")

#range 18-19:
num_age18 = len(df[df['age'] == 18])
num_age19 = len(df[df['age'] == 19])

print(f"\n\nThere are: \n - {num_age18} students that are 18 years old", end = "")
print(f"\n - {num_age19} students that are 19 years old")
print(f"\nMeaning that the bin '18-19' should comprehend {num_age18 + num_age19} students")

#range 20-22
num_age20 = len(df[df['age'] == 20])
num_age21 = len(df[df['age'] == 21])
num_age22 = len(df[df['age'] == 22])

print(f"\n\nThere are: \n - {num_age20} students that are 20 years old", end = "")
print(f"\n - {num_age21} students that are 21 years old", end = "")
print(f"\n - {num_age22} students that are 22 years old")
print(f"\nMeaning that the bin '20-22' should comprehend {num_age20 + num_age21 + num_age22} students")
# Out:
# The students' minimum age found in the dataset is: 15
# The students' maximum age found in the dataset is: 22
#
#
# There are:
#  - 194 students that are 15 years old
#  - 281 students that are 16 years old
#  - 277 students that are 17 years old
#
# Meaning that the bin '15-17' should comprehend 752 students
#
#
# There are:
#  - 222 students that are 18 years old
#  - 56 students that are 19 years old
#
# Meaning that the bin '18-19' should comprehend 278 students
#
#
# There are:
#  - 9 students that are 20 years old
#  - 3 students that are 21 years old
#  - 2 students that are 22 years old
#
# Meaning that the bin '20-22' should comprehend 14 students

# %% [markdown]
# Now lets create the bins and check if some error occured by comparing the number of students in each newly created group with the numbers computed in the last cell of code:

# %%
df_new['age'] = pd.cut(
                       x = df_new['age'],                       #considering only the 'age' columns
                       bins = [min_age, 17, 19, max_age],       #[15-22] becomes [15-17], [18-19], [20,21]
                       labels = ["15-17","18-19", "20-22"],     #labels to assign to above bins
                       right = True,                            #include right most element (...]
                       include_lowest=True                      #include left most element  [...)
                      )

df_new['age'] = df_new['age'].astype(str)

print(f"The bin counts are: \n\n{df_new['age'].value_counts()}")
# Out:
# The bin counts are:
#
# 15-17    752
# 18-19    278
# 20-22     14
# Name: age, dtype: int64

# %% [markdown]
# <p id="discretizing_G3"></p>
#
# #### 1.3 Discretizing G3

# %% [markdown]
# The feauture `age` is not the only one that should be discretized. In [this article](https://www.scholaro.com/db/Countries/Portugal/Grading-System), we found out that the grade `G3` can be discretized as follows:
#
# |Grade||Description||Translation|
# |:----------||:--------------||:-----------------|
# |20.00||Muito bom con distincao e louvor||Very good with distinction and honors|
# |18.00 - 19.99||Excelente||Excellent|
# |16.00 - 17.99||Muito Bom||Very Good|
# |14.00 - 15.99||Bom||Good|
# |10.00 - 13.99||Suficiente||Sufficient|
# |7.00 - 9.99||Mediocre||Poor|
# |0.00 - 6.99||Mau||Poor|
#
#
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
#range mau: 
num_mau = (len(df_new[df_new['G3'] == 0]) + len(df_new[df_new['G3'] == 1]) + len(df_new[df_new['G3'] == 2]) + len(df_new[df_new['G3'] == 3]) + len(df_new[df_new['G3'] == 4]) + len(df_new[df_new['G3'] == 5]) + len(df_new[df_new['G3'] == 6]))
            
print(f"There are {num_mau} students that obtained Mau")

#range mediocre
num_med = len(df_new[df_new['G3'] == 7]) + len(df_new[df_new['G3'] == 8]) + len(df_new[df_new['G3'] == 9])
print(f"\nThere are {num_med} students that obtained Mediocre")

#range suficiente 
num_suf = len(df_new[df_new['G3'] == 10]) + len(df_new[df_new['G3'] == 11]) + len(df_new[df_new['G3'] == 12]) + len(df_new[df_new['G3'] == 13])
print(f"\nThere are {num_suf} students that obtained Suficiente")
                     
#range bom 
num_bom = len(df_new[df_new['G3'] == 14]) + len(df_new[df_new['G3'] == 15])
print(f"\nThere are {num_bom} students that obtained Bom")
                     
#range muito bom 
num_muitobom = len(df_new[df_new['G3'] == 16]) + len(df_new[df_new['G3'] == 17])
print(f"\nThere are {num_muitobom} students that obtained Muito bom")
                     
#range excelente 
num_exc = len(df_new[df_new['G3'] == 18]) + len(df_new[df_new['G3'] == 19])
print(f"\nThere are {num_exc} students that obtained Excelente")
                     
#range muito bom con distincao e louvor
num_muitobomdist = len(df_new[df_new['G3'] == 20])
print(f"\nThere are {num_muitobomdist} students that obtained Muito bom con distincao e louvor")
# Out:
# There are 81 students that obtained Mau
#
# There are 149 students that obtained Mediocre
#
# There are 520 students that obtained Suficiente
#
# There are 172 students that obtained Bom
#
# There are 87 students that obtained Muito bom
#
# There are 34 students that obtained Excelente
#
# There are 1 students that obtained Muito bom con distincao e louvor

# %% [markdown]
# Now lets create the bins and check if some error occured by comparing the number of students in each newly created group with the numbers computed in the last cell of code:

# %%
ordered_labels = ["Mau",
                  "Mediocre", 
                  "Suficiente",
                  "Bom",
                  "Muito Bom",
                  "Excelente",
                  "Mui bom distincao"
                 ]


df_new['G3'] = pd.cut(x = df_new['G3'], 
                      bins = [np.min(df_new['G3']),6.99,9.99,13.99,15.99,17.99,19.99,np.max(df_new['G3'])], 
                      labels = ordered_labels,
                      right = True,
                      include_lowest = True)

df_new['G3'] = df_new['G3'].astype(str)

print(f"The bin counts are: \n\n{df_new['G3'].value_counts()}")
# Out:
# The bin counts are:
#
# Suficiente           520
# Bom                  172
# Mediocre             149
# Muito Bom             87
# Mau                   81
# Excelente             34
# Mui bom distincao      1
# Name: G3, dtype: int64

# %% [markdown]
# <p id="discretizing_absences"></p>
#
# #### 1.4 Discretizing absences

# %% [markdown]
# The last feature that should be discretized is `absences`:

# %%
df_new['absences'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# By looking at the previous histogram, we decided to discretize the values of `absebces` as follows:
#
# - `0-10`
# - `11-20`
# - `21-30`
# - `+30`
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
ordered_labels = ["0-10","11-20", "21-30", "+30"]

df_new['absences'] = pd.cut(x = df_new['absences'], 
                            bins = [np.min(df_new['absences']),10,20,30,np.max(df_new['absences'])], 
                            labels = ordered_labels,
                            right = True,
                            include_lowest = True)

df_new['absences'] = df_new['absences'].astype(str)

# %% [markdown]
# <p id="discretizing_results"></p>
#
# #### 1.5 Results of the discretization step

# %% [markdown]
# <a href = "#index"><b>*back to the top*</b></a>
#
# Let's observe the distribution of the discretized features represented on histograms and print the new dataset's structure:

# %%
discretized = [df_new['age'], 
               df_new['G3'], 
               df_new['absences']]

titles = ["Age of the students", 
          "Final grade of the students", 
          "Number of absences of the students"]

bins = [["15-17","18-19", "20-22"], 
        ["Mau", "Mediocre",  "Suficiente", "Bom", "Muito Bom", "Excelente", "Mui bom distincao" ],
        ["0-10","11-20", "21-30", "+30"]]

fig, x = plt.subplots(1, len(discretized), figsize=(20, 7))

for i in range(len(x)):
    x[i].bar(bins[i], discretized[i].value_counts(), width = 0.3)
    x[i].grid(True)
    x[i].set_title(titles[i])
    if i == 1:
        _ = plt.setp(x[i].get_xticklabels(), rotation=45)

fig.show()
# Out:
# <ipython-input-12-8ed060ad9430>:22: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#Preprocessed dataset's structure info:
print("The preprocessed dataset has the following structure:\n")
print(f"Number of features per individual:\t{len(df_new.columns)}")
print(f"Number of individuals in the dataset:\t{len(df_new)}")
print(f"\nColumns names:\n")

for i in range(len(df_new.columns)):
    print(f"{i}. {df_new.columns[i]}")

print("\nRepresentation of the first five individuals of the dataset:")
df_new.head()
# Out:
# The preprocessed dataset has the following structure:
#
# Number of features per individual:	18
# Number of individuals in the dataset:	1044
#
# Columns names:
#
# 0. sex
# 1. age
# 2. Pstatus
# 3. Medu
# 4. Fedu
# 5. studytime
# 6. failures
# 7. schoolsup
# 8. famsup
# 9. paid
# 10. activities
# 11. famrel
# 12. freetime
# 13. goout
# 14. Dalc
# 15. health
# 16. absences
# 17. G3
#
# Representation of the first five individuals of the dataset:
#   sex    age Pstatus  Medu  Fedu  studytime  failures schoolsup famsup paid  \
# 0   F  18-19       A     4     4          2         0       yes     no   no
# 1   F  15-17       T     1     1          2         0        no    yes   no
# 2   F  15-17       T     1     1          2         3       yes     no  yes
# 3   F  15-17       T     4     2          3         0        no    yes  yes
# 4   F  15-17       T     3     3          2         0        no    yes  yes
#
#   activities  famrel  freetime  goout  Dalc  health absences          G3
# 0         no       4         3      4     1       3     0-10         Mau
# 1         no       5         3      3     1       3     0-10         Mau
# 2         no       4         3      2     2       3     0-10  Suficiente
# 3        yes       3         2      2     1       5     0-10         Bom
# 4         no       4         3      2     1       5     0-10  Suficiente

# %% [markdown]
# ## 2. Data Exploration
#
# <p id="data_exploration"></p>
#
# In order to build our Bayesian Network, we must analyze the relationships between each pair of features. In this way, we are able to build a good Bayesian model and formulate correct inferences.
#
# <a href = "#index"><b>*back to the top*</b></a>
#
# Let's now have a look at the attributes that, in our opinion, have high influence on others:

# %% [markdown]
# <p id="Pstatus_famrel"></p>
#
# ### 2.1. Pstatus $\rightarrow$ famrel
#
# In our opinion, the fact that parents are together or apart affects the relation with their son/daughter.

# %%
#parameters
a,b = 'Pstatus', 'famrel'
a_order = ['A','T']

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b, 
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='Pstatus', ylabel='percentage'>

# %% [markdown]
# The countplot shows that when `Pstatus = A` the occurrences of low values of `famrel` are slightly higher and the high values of `famrel` are slightly lower w.r.t. the case in which `Pstatus = T`. This means that
#
# **<div align="center">`Pstatus` influences `famrel`.</div>**

# %% [markdown]
# <p id="famrel_famsup"></p>
#
# ### 2.2. famrel $\rightarrow$ famsup
# Intuitively, if a student has a good relationship with his parents, he will more likely be academically supported.

# %%
#parameters
a,b = 'famrel', 'famsup'
a_order = [1,2,3,4,5]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b, 
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='famrel', ylabel='percentage'>

# %% [markdown]
# In the previous plot we can see that `famrel` has minimal changes on its trend when `famsup` varies. The only case where the trend is slightly different from the others is for `famrel = 4`, indeed in this case the gap between the two coloumns is a little bit higher. In conclusion, we can say that having a good family relationship does not really imply that a student will be supported academically by his parents:
#
# **<div align="center">`famrel` does not influence `famsup`.</div>**

# %% [markdown]
# <p id="famrel_Dalc"></p>
#
# ### 2.3. famrel $\rightarrow$ Dalc
# A student that has a bad family relationship may be more prone to the possibility of drinking too much.

# %%
#parameters
a,b = 'famrel', 'Dalc'
a_order = [1,2,3,4,5]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='famrel', ylabel='percentage'>

# %% [markdown]
# The countplot shows that increasing the value of `famrel`, the amount of occurrencies of low values of `Dalc` increases and viceversa the amount of occurrencies of high values of `Dalc` decreases.
#
# **<div align="center">`famrel` influences `Dalc`.</div>**

# %% [markdown]
# <p id="Medu/Fedu_famsup"></p>
#
# ### 2.4. Medu/Fedu $\rightarrow$ famsup
#
# <p id="famsup_block"></p>
#
# Mother's level of education should influence the family support value.

# %%
#parameters
a,b = 'Medu', 'famsup'
a_order = [0,1,2,3,4]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='Medu', ylabel='percentage'>

# %% [markdown]
# As expected, higher is the mother's level of education, more likely `famsup` is equal to *'yes'*.
# This previous point is valid also for the father's level of education meaning that:
#
# **<div align="center">`Medu` and `Fedu` both influence `famsup`.</div>**

# %% [markdown]
# <p id="famsup_paid"></p>
#
# ### 2.5. famsup $\rightarrow$ paid
# A student that has family support in his academic carreer, morelikely will go to extra paid lessons.

# %%
#parameters
a,b = 'famsup', 'paid'
a_order = ['yes', 'no']

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='famsup', ylabel='percentage'>

# %% [markdown]
# The countplot shows that there is a slightly higher chance that a student attends extra paid lesson if his academic career is supported by his family, meaning that:
#
# **<div align="center">`famsup` influences `paid`.</div>**

# %% [markdown]
# <p id="paid_G3"></p>
#
# ### 2.6. paid $\rightarrow$ G3
# A student that goes to additional paid lessons might achieve higher grades than the rest:

# %%
#parameters
a,b = 'paid', 'G3'
a_order = ['no', 'yes']
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            hue_order = hue_order,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# The trend is the opposite of what we expected. In particular, attending paid lessons doesn't really change the occurrencies of the grades:
#
# **<div align="center">`paid` does not affect `G3`.</div>**

# %% [markdown]
# <p id="freetime_goout"></p>
#
# ### 2.7. freetime $\rightarrow$ goout
# <p id="freetime_block"></p>
# A student with a lot of freetime might spend it to go out with friends:

# %%
#parameters
a,b = 'freetime', 'goout' 
a_order = [1,2,3,4,5]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='freetime', ylabel='percentage'>

# %% [markdown]
# The countplot shows that students with a lot of freetime are a lot more prone to go out with friends:
#
# **<div align="center">`freetime` influences `goout`.</div>**

# %% [markdown]
# <p id="freetime_activities"></p>
#
# ### 2.8. freetime $\rightarrow$ activities
# a student that has a lot of free time might use it for various extracurricular activities

# %%
#parameters
a,b = 'freetime', 'activities' 
a_order = [1,2,3,4,5]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='freetime', ylabel='percentage'>

# %% [markdown]
# The countplot shows that with higher values of free time, the chance that a student participates to extracurricular activities is much higher. Oppositely, who has `freetime = 1` has a higher chance to attend extracurricular activities.
#
# **<div align="center">`freetime` influences `activities`.</div>**

# %% [markdown]
# <p id="goout_studytime"></p>
#
# ### 2.9. goout $\rightarrow$ studytime
# A student that goes out with his friends too much, might not have a lot of time to study left.

# %%
#parameters
a,b = 'goout', 'studytime'
a_order = [1,2,3,4,5]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='goout', ylabel='percentage'>

# %% [markdown]
# As we can see from the countplot, middle values of `goout` correspond to higher values of `studytime`:
#
# **<div align="center">`goout` influences `studytime`.</div>**

# %% [markdown]
# <p id="activities_studytime"></p>
#
# ### 2.10. activities $\rightarrow$ studytime
# A student that participates to extracurricular activities might have less time left to study:

# %%
#parameters
a,b = 'activities', 'studytime'
a_order = ['no', 'yes']

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='activities', ylabel='percentage'>

# %% [markdown]
# As we can see, when `activities = yes` the occurrences of `studytime` equal to `2`, `3` or `4` are higher and the occurences of `studytime = 1` are lower. For these reasons, we can say:
#
# **<div align="center">`activities` influences `studytime`.</div>**

# %% [markdown]
# <p id="famsup_studytime"></p>
#
# ### 2.11. famsup $\rightarrow$ studytime
#
# <p id="studytime_block"></p>
#
# Parents that support their son's/daughter's academic career are more likely to influence the amount of studytime of their children.

# %%
#parameters
a,b = 'famsup', 'studytime'
a_order = ['yes','no']

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='famsup', ylabel='percentage'>

# %% [markdown]
# The countplot shows that `studytime` varies its trend while changing `famsup`. As a matter of fact, if `famsup = 'yes'` the gap between the orange bar and the blu bar is much bigger than in the case of `famsup = 'no'`. This means that not receiving parental academic support implies a greater occurrence of students who study for a shorter amount of time. For this reason we can say that:
#
# **<div align="center">`famsup` influences `studytime`.</div>**

# %% [markdown]
# <p id="Dalc_studytime"></p>
#
# ### 2.12. Dalc $\rightarrow$ studytime
#
# Workday alcohol consumption should negatively affect the amount of studytime. Let's see if the data confirms this trend.

# %%
#parameters
a,b = 'Dalc', 'studytime'
a_order = [1,2,3,4]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True


#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])
# Out:
# <AxesSubplot:title={'center':'Normalized Countplot'}, xlabel='Dalc', ylabel='percentage'>

# %% [markdown]
# In the previous countplot we can see that the higher is the workday alcohol consumption, approximately the less studytime there will be, meaning that:
#
# **<div align="center">`Dalc` influences `studytime`.</div>**

# %% [markdown]
# <p id="health_studytime"></p>
#
# ### 2.13. health $\rightarrow$ studytime
#
# Students' health conditions should affect their studytime, as a matter of fact, if a student has severe health problems, unfortunately he might not be in the conditions to study.

# %%
#parameters
a,b = 'health', 'studytime'
a_order = [1,2,3,4]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='studytime', ncol = 4)

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='studytime', ncol = 4)

# %% [markdown]
# This plot is a little particular. Specifically, we can see that if a student's health conditions are very bad, `studytime = 2` has still a lot of occurences, meaning that even though the health conditions are not good, a high percentage of students will still manage to study for 2-5 hours per week. Instead, if we consider `studytime = 3`, we can notice that the better the health conditions are, the higher will be the percentage of students that study 5-10 hours per week. But also, if we consider `studytime = 1`, we observe that better health conditions correspond to more occurrences of students that study less than 2 hours per week. For this previous reasons, we can say that:
#
# **<div align="center">`health` does not influences `studytime`.</div>**

# %% [markdown]
# <p id="schoolsup_studytime"></p>
#
# ### 2.14. schoolsup $\rightarrow$ studytime
#
# Intuitively, `schoolsup` should affect the amount of studytime, because students that are supported by their school might be highly motivated to succed in their classes.

# %%
#parameters
a,b = 'schoolsup', 'studytime'
a_order = ["yes", "no"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='studytime', ncol = 4)

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='studytime', ncol = 4)

# %% [markdown]
# From the previous plot, we can comprehend that, without the support of their school, students study less hours than
# the students that receive school support, as we can see that `studytime = 1` is much higher in the case of `schoolsup = no` and inversively much lower when `schoolsup = yes`. For these previous reasons:
#
# **<div align="center">`schoolsup` influences `studytime`.</div>**

# %% [markdown]
# <p id="age_G3"></p>
#
# ### 2.15. age $\rightarrow$ G3
#
# <p id="G3_block"></p>
#
# The students' age may affect their final grade because of the fact that we discretized in three ranges of age, separating students that never failed from students that failed one or more times.

# %%
#parameters
a,b = 'age', 'G3'
a_order = ["15-17","18-19", "20-22"]
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b, 
              order = a_order,
              hue_order = hue_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))


#normalized countplot:
occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            order = a_order,
            hue_order = hue_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].set_title("Normalized Countplot")
ax[1].grid = True
ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# Approximately, we can say that the higher it gets the students' range of age, the higher is the amount of occurrencies of not sufficient final grades and oppositely the amount of occurrencies of sufficient grades decreases. For this reason we can say that:
#
# **<div align="center">`age` influences `G3`.</div>**

# %% [markdown]
# <p id="sex_G3"></p>
#
# ### 2.16. sex $\rightarrow$ G3
#
# Let's check if the sex of a student affects the final grade.

# %%
#parameters
a,b = 'sex', 'G3'
a_order = ["F", "M"]
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b,
              hue_order = hue_order,
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            hue_order = hue_order,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# From the previous countplot, we can observe that female students are slightly more likely prone to get higher grades than male students. As a matter of fact, if we consider grades below *sufficient* there are more male occurrencies; oppositely for grades higher that *sufficient* there are more female occurrencies;
# The previous points show that:
#
# **<div align="center">`sex` affects `G3`.</div>**

# %% [markdown]
# <p id="absences_G3"></p>
#
# ### 2.17. absences $\rightarrow$ G3
#
# The number of absences may influence the students' final grade.

# %%
#parameters
a,b = 'absences', 'G3'
a_order = ["0-10","11-20", "21-30", "+30"]
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b,
              hue_order = hue_order,
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            hue_order = hue_order,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# As we can see, if the number of a student's absences gets high, the number of occurrencies of the grades below `suficiente` also gets higher. For this reason we can say that:
#
# **<div align="center">`absences` influences `G3`.</div>**

# %% [markdown]
# <p id="famsup_G3"></p>
#
# ### 2.18. famsup $\rightarrow$ G3
# A student that has a good academic support from his parents, might study with greater commitment, resulting in a better final grade.

# %%
#parameters
a,b = 'famsup', 'G3'
a_order = ['yes','no']
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b,
              hue_order = hue_order,
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            hue_order = hue_order,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# Also in this case we can observe that `famsup` doesn't really affect `G3`:
#
# **<div align="center">`famsup` does not influences `G3`.</div>**

# %% [markdown]
# <p id="studytime_G3"></p>
#
# ### 2.19. studytime $\rightarrow$ G3
#
# The amount of studytime of a student should positively affect his final grade.

# %%
#parameters
a,b = 'studytime', 'G3'
a_order = [1,2,3,4]
hue_order = ["Mau",
             "Mediocre", 
             "Suficiente",
             "Bom",
             "Muito Bom",
             "Excelente",
             "Mui bom distincao"]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

#countplot:
sns.countplot(data = df_new,
              x = a,
              hue = b,
              hue_order = hue_order,
              order = a_order,
              ax = ax[0])

ax[0].set_title("Countplot")
ax[0].grid = True
ax[0].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

#normalized countplot:
ax[1].set_title("Normalized Countplot")
ax[1].grid = True

occupation_counts = (df_new.groupby([a])[b]
                     .value_counts(normalize = True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values(b))

sns.barplot(x = a, 
            y = "percentage", 
            hue = b,
            hue_order = hue_order,
            order = a_order,
            data = occupation_counts, 
            ax = ax[1])

ax[1].legend(title='G3', ncol=3, bbox_to_anchor = (0.95, -0.12))

# %% [markdown]
# By looking at the previous countplot, we can clearly observe that students that study for a longer amount of time obtain higher grades and oppositely students that study less obtain lower grades. For this reason we can say that:
#
# **<div align="center">`studytime` influences `G3`.</div>**

# %% [markdown]
# Taking into account all of the previous considerations, we decided to drop the following features from the dataset:
#
# - `paid`, which doesn't affect the final grade in any possible way;
# - `health`, which doesn't affect the final grade either.

# %%
df_new = df_new.drop(['paid', 'health'], axis=1)
df_new.head()
# Out:
#   sex    age Pstatus  Medu  Fedu  studytime  failures schoolsup famsup  \
# 0   F  18-19       A     4     4          2         0       yes     no
# 1   F  15-17       T     1     1          2         0        no    yes
# 2   F  15-17       T     1     1          2         3       yes     no
# 3   F  15-17       T     4     2          3         0        no    yes
# 4   F  15-17       T     3     3          2         0        no    yes
#
#   activities  famrel  freetime  goout  Dalc absences          G3
# 0         no       4         3      4     1     0-10         Mau
# 1         no       5         3      3     1     0-10         Mau
# 2         no       4         3      2     2     0-10  Suficiente
# 3        yes       3         2      2     1     0-10         Bom
# 4         no       4         3      2     1     0-10  Suficiente

# %% [markdown]
# ## 3. Bayesian Network Implementation and Analysis
# <p id="bnia"></p>
#
# With all of the considerations made in the previous section, we are now able to build the network and analyse closely the nodes' relationships.
#
# Let's start creating the network by defining the building blocks which will later be merged.
#
# <a href = "#index"><b>*back to the top*</b></a>

# %% [markdown]
# ### 3.1. The `Dalc` block
#
# <p id="Dalc_block"></p>
#
# In <a href="#dalc_block">*section 2.1.*</a> we found out that `Pstatus` influences `famrel` and `famrel` influences `Dalc`.

# %%
#----------Definition of the building block----------

block1 = BayesianNetwork([
                         ('Pstatus','famrel'),
                         ('famrel','Dalc')
                       ])

#--------Representation of the building block--------

#Nodes Coordinates:
pos1 = {"Pstatus":  (0,2),
        "famrel":   (0,1), 
        "Dalc":     (0,0),    
      }

#Options:
options1 = {
    'node_size': 2000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(3.5, 3.5))
nx.draw(block1, pos=pos1, node_color="orange", with_labels=True, **options1)

# %% [markdown]
# By observing the above graph, we can spot a *causal trail* dependency:
#
# #### Causal trail
# When we have a ***causal trail***, we can say that if `famrel` is observed then `Pstatus` and `Dalc` are statistically independent; contrarily if `famrel` is not observed then `Pstatus` and `Dalc` are statistically dependent.
#
# Also, with causal trails we say that the two-edge trail X $\rightarrow$ Z $\rightarrow$ Y is active if X $\not \perp$ Y.
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`Pstatus` $\perp$ `Dalc` $|$ `famrel`||*inactive two-edge trail*|
# |`Pstatus` $\not\perp$ `Dalc`||*active two-edge trail*|

# %% [markdown]
# ### 3.2. The `famsup` block
#
# <p id="Famsup_block"></p>
#
# In <a href="#famsup_block">*section 2.4.*</a> we found out that:
#
# - `Medu` and `Fedu` both infuence `famsup`;

# %%
#----------Definition of the building block----------

block2 = BayesianNetwork([
                         ('Medu','famsup'),
                         ('Fedu','famsup')
                       ])

#--------Representation of the building block--------

#Nodes Coordinates:
pos2 = {"Medu":   (0,1),
        "Fedu":   (2,1), 
        "famsup": (1,0),    
      }

#Options:
options2 = {
    'node_size': 2000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(3.5, 3.5))
nx.draw(block2, pos=pos2, node_color="orange", with_labels=True, **options2)

# %% [markdown]
# By observing the above graph, we can spot a *V-Structure dependency*.
#
# #### V-Structure (common cause)
# When we have a V-Structure, we can say that `Medu` and `Fedu` are statistically independent if `famsup` is unobserved, but in the case `famsup` is observed, we have that `Medu`and `Fedu` are statistically dependent.
#
# Also, with *v-structures*, we say that the two-edge trail X $\rightarrow$ Z $\leftarrow$ Y is active if X $\not \perp$ Y $|$ Z.
#
# |Dependencies||two-edge trail type|
# |:-------------||:--------------|
# |`Medu` $\not \perp$ `Fedu` $|$ `famsup`||*active two-edge trail*|
# |`Medu` $\perp$ `Fedu`||*inactive two-edge trail*|

# %% [markdown]
# ### 3.3. The `freetime` block
#
# <p id="Freetime_block"></p>
#
# In <a href="#freetime_block">*section 2.7, 2.8, 2.9, 2.10*</a> we found out that`freetime` influences both `goout` and `activities`:

# %%
#----------Definition of the building block----------

block3 = BayesianNetwork([
                         ('freetime','goout'),
                         ('freetime','activities')
                       ])

#--------Representation of the building block--------

#Nodes Coordinates:
pos3 = {"freetime":   (1,1),
        "goout":      (0,0), 
        "activities": (2,0),    
      }

#Options:
options3 = {
    'node_size': 2000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(3.5, 3.5))
nx.draw(block3, pos=pos3, node_color="orange", with_labels=True, **options3)

# %% [markdown]
# #### Common parent stucture
#
# The above graph represents a ***common parent structure***, meaning that if `freetime` is observed then `goout` and `activities` are statistically independent; contrarily if `freetime` is not observed then `goout` and `activities` are statistically dependent. Summarizing we have that:
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`goout` $\perp$ `activities` $|$ `freetime`||*active two-edge trail*|
# |`goout` $\not\perp$ `activities`||*inactive two-edge trail*|

# %% [markdown]
# ### 3.4. The `studytime` block
#
# <p id="Studytime_block"></p>
#
# In <a href="#studytime_block">*section 2.11, 2.12, 2.13, 2.14*</a> we found out that`famsup`, `schoolsup`, `goout`, `activities` and `Dalc` all infuence `studytime`.

# %%
#----------Definition of the building block----------

block4 = BayesianNetwork([
                         ('schoolsup','studytime'),
                         ('famsup','studytime'),
                         ('Dalc','studytime'),
                         ('activities','studytime'),
                         ('goout', 'studytime')
                       ])

#--------Representation of the building block--------

#Nodes Coordinates:
pos4 = {'schoolsup' : (0,1),
       'famsup' : (1,1),
       'studytime' : (2,0),     
       'Dalc' : (2,1),  
       'traveltime' : (3,1),  
       'goout' : (4,1),
       'activities' : (5,1),
        
      }

#Options:
options4 = {
    'node_size': 3000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(4.5, 4.5))
nx.draw(block4, pos=pos4, node_color="orange", with_labels=True, **options4)

# %% [markdown]
# In the above graph, there are only ***v-structures*** as all of the nodes point towards `studytime`. Because of this, we can conclude the following:
#
# <br>
#
# * `schoolsup` $\rightarrow$ `studytime` $\leftarrow$ `famsup`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`schoolsup` $\perp$ `famsup`||*inactive two-edge trail*|
# |`schoolsup` $\not \perp$ `famsup` $|$ `studytime`||(*active two-edge trail*)|
#
# <br>
#
# * `schoolsup` $\rightarrow$ `studytime` $\leftarrow$ `Dalc`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`schoolsup` $\perp$ `Dalc`||*inactive two-edge trail*|
# |`schoolsup` $\not \perp$ `Dalc` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `schoolsup` $\rightarrow$ `studytime` $\leftarrow$ `goout`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`schoolsup` $\perp$ `goout`||*inactive two-edge trail*|
# |`schoolsup` $\not \perp$ `goout` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `schoolsup` $\rightarrow$ `studytime` $\leftarrow$ `activities`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`schoolsup` $\perp$ `activities`||*inactive two-edge trail*|
# |`schoolsup` $\not \perp$ `activities` $|$ `studytime`||*active two-edge trail*|
#
#
# <br>
#
# * `famsup` $\rightarrow$ `studytime` $\leftarrow$ `Dalc`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`famsup` $\perp$ `Dalc`||*inactive two-edge trail*|
# |`famsup` $\not \perp$ `Dalc` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `famsup` $\rightarrow$ `studytime` $\leftarrow$ `activities`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`famsup` $\perp$ `activities`||*inactive two-edge trail*|
# |`famsup` $\not \perp$ `activities`  $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `famsup` $\rightarrow$ `studytime` $\leftarrow$ `goout`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`famsup` $\perp$ `goout`||*inactive two-edge trail*|
# |`famsup` $\not \perp$ `goout` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `Dalc` $\rightarrow$ `studytime` $\leftarrow$ `goout`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`Dalc` $\perp$ `goout`||*inactive two-edge trail*|
# |`Dalc` $\not\perp$ `goout` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `Dalc` $\rightarrow$ `studytime` $\leftarrow$ `activities`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`Dalc` $\perp$ `activities`||*inactive two-edge trail*|
# |`Dalc` $\not\perp$ `activities` $|$ `studytime`||*active two-edge trail*|
#
# <br>
#
# * `goout` $\rightarrow$ `studytime` $\leftarrow$ `activities`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`goout` $\perp$ `activities`||*inactive two-edge trail*|
# |`goout` $\not\perp$ `activities` $|$ `studytime`||*active two-edge trail*|

# %% [markdown]
# ### 3.5. The `G3` block
#
# <p id="g3_block"></p>
#
# In <a href="#G3_block">*section 2.15, 2.16, 2.17, 2.18, 2.19, 2.20*</a> we found out that`studytime`, `age`, `sex` and `absences` all infuence `G3`.

# %%
#----------Definition of the building block----------

block5 = BayesianNetwork([
                         ('studytime','G3'),
                         ('age','G3'),
                         ('sex','G3'),
                         ('absences','G3')
                       ])

#--------Representation of the building block--------

#Nodes Coordinates:
pos5 = {'studytime' : (0,1),
       'G3' : (2,0),     
       'age' : (1,1),  
       'sex' : (3,1),  
       'absences' : (4,1),
      }

#Options:
options5 = {
    'node_size': 3000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(4.5, 4.5))
nx.draw(block5, pos=pos5, node_color="orange", with_labels=True, **options5)

# %% [markdown]
# Just as it happened earlier, in the above graph there are only ***v-structures***, but differently this time all of the nodes point towards `G3`. Because of this, we can conclude the following:
#
# <br>
#
# * `studytime` $\rightarrow$ `G3` $\leftarrow$ `age`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`studytime` $\perp$ `age`||*inactive two-edge trail*|
# |`studytime` $\not \perp$ `age` $|$ `G3`||*active two-edge trail*|
#
# <br>
#
# * `studytime` $\rightarrow$ `G3` $\leftarrow$ `sex`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`studytime` $\perp$ `sex`||*inactive two-edge trail*|
# |`studytime` $\not \perp$ `sex`  $|$ `G3`||*active two-edge trail*|
#
# <br>
#
# * `studytime` $\rightarrow$ `G3` $\leftarrow$ `absences`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`studytime` $\perp$ `absences`||*inactive two-edge trail*|
# |`studytime` $\not \perp$ `absences` $|$ `G3`||*active two-edge trail*|
#
# <br>
#
# * `age` $\rightarrow$ `G3` $\leftarrow$ `sex`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`age` $\perp$ `sex`||*inactive two-edge trail*|
# |`age` $\not\perp$ `sex` $|$ `G3`||*active two-edge trail*|
#
# <br>
#
# * `age` $\rightarrow$ `G3` $\leftarrow$ `absences`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`age` $\perp$ `absences`||*inactive two-edge trail*|
# |`age` $\not\perp$ `absences` $|$ `G3`||*active two-edge trail*|
#
# <br>
#
# * `sex` $\rightarrow$ `G3` $\leftarrow$ `absences`
#
# |Dependencies||two-edge trail type|
# |:-------------||--------------:|
# |`sex` $\perp$ `absences`||*inactive two-edge trail*|
# |`sex` $\not\perp$ `absences` $|$ `G3`||*active two-edge trail*|

# %% [markdown]
# ### 3.6. The resulting network
#
# <p id="resulting_network"></p>
#
# Let's now put all the building blocks together:

# %%
#----------Definition of the Bayesian Network----------

model = BayesianNetwork([
                         #famsup block:
                         ('Medu','famsup'),
                         ('Fedu','famsup'),
    
                         #freetime block:
                         ('freetime','goout'),
                         ('freetime','activities'),
    
                         #Dalc block:
                         ('Pstatus','famrel'),
                         ('famrel','Dalc'),
    
                         #studytime block:
                         ('schoolsup','studytime'),
                         ('famsup','studytime'),
                         ('Dalc','studytime'),
                         ('goout','studytime'),
                         ('activities','studytime'),
                        
                         #G3 block: 
                         ('sex','G3'),   
                         ('age','G3'),
                         ('studytime','G3'),
                         ('absences','G3'),
                       ])

#--------Representation of the Bayesian Network--------

#Nodes Coordinates:
pos = {"Medu": (0,5),
       "Fedu": (2,5),
       "famsup": (1,4),
       
       "freetime": (4,5),
       "goout": (3,4),
       "activities": (5,4),  
       
       "Pstatus": (7,5),
       "famrel": (7,4),
       "Dalc": (7,3),
       
       "schoolsup": (0,3),
       
       "studytime": (4,2),
       
       "sex": (3,1), 
       "age": (3,0),  
       "absences": (5,1), 
       "G3": (4,0)
      }

#Options:
options = {
    'node_size': 3000,
    'width': 1,
    'arrowsize': 20,
    'font_size': 10
}     
        
plt.figure(figsize=(12, 8))
nx.draw(model, pos=pos, node_color="orange", with_labels=True, **options)

# %% [markdown]
# ### 3.7. Analysis of the resulting network: flow of probabilistic influence
#
# <p id="analysis"></p>
#
# Since the network has been successfully created, let's verify the dependencies analyzed earlier by using the adequate *pgmpy* functions.
#
# #### Active trails
# A trail that has more than three edges, is considered ***active*** if all the two-edge trails that compose it are active; one inactive two-edge trail makes the entire trail inactive.
#
# <a href = "#index"><b>*back to the top*</b></a>
#
# Let's see how all of the active trails change if variables are observed:

# %%
#nodes:

nodes = ['Medu', 
         'Fedu', 
         'famsup',
         'freetime',
         'goout',
         'activities',
         'Pstatus',
         'famrel',
         'Dalc',
         'schoolsup', 
         'studytime', 
         'sex', 
         'age', 
         'G3', 
         'absences']

observed_nodes = ['famsup', 
                  'famsup', 
                  'studytime', 
                  ['goout','activities'], 
                  'studytime', 
                  'studytime', 
                  'famrel', 
                  'Dalc', 
                  'studytime',
                  'studytime',
                  'G3', 
                  'G3',
                  'G3',
                  'studytime', 
                  'G3']

#Active trails:

for i in range(len(nodes)):
    print(f"\n\n- Active trails from node '{nodes[i]}':\n")
    a = model.active_trail_nodes(nodes[i])
    print(f"{a[nodes[i]]}")
    print(f"\n\n- Active trails from node '{nodes[i]}' given that '{observed_nodes[i]}' is observed: ")
    b = model.active_trail_nodes(nodes[i], observed = observed_nodes[i])
    print(f"\n{b[nodes[i]]}\n")
    print("-"*55)
# Out:
# - Active trails from node 'Medu':
#
# {'studytime', 'Medu', 'famsup', 'G3'}
#
#
# - Active trails from node 'Medu' given that 'famsup' is observed:
#
# {'Medu', 'Fedu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'Fedu':
#
# {'studytime', 'famsup', 'Fedu', 'G3'}
#
#
# - Active trails from node 'Fedu' given that 'famsup' is observed:
#
# {'Medu', 'Fedu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'famsup':
#
# {'Fedu', 'famsup', 'G3', 'studytime', 'Medu'}
#
#
# - Active trails from node 'famsup' given that 'studytime' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'freetime', 'Dalc', 'schoolsup', 'goout', 'Pstatus', 'Medu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'freetime':
#
# {'studytime', 'activities', 'goout', 'G3', 'freetime'}
#
#
# - Active trails from node 'freetime' given that '['goout', 'activities']' is observed:
#
# {'freetime'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'goout':
#
# {'studytime', 'activities', 'goout', 'G3', 'freetime'}
#
#
# - Active trails from node 'goout' given that 'studytime' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'freetime', 'Dalc', 'schoolsup', 'goout', 'Pstatus', 'Medu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'activities':
#
# {'studytime', 'activities', 'goout', 'G3', 'freetime'}
#
#
# - Active trails from node 'activities' given that 'studytime' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'freetime', 'Dalc', 'schoolsup', 'goout', 'Pstatus', 'Medu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'Pstatus':
#
# {'Dalc', 'famrel', 'Pstatus', 'studytime', 'G3'}
#
#
# - Active trails from node 'Pstatus' given that 'famrel' is observed:
#
# {'Pstatus'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'famrel':
#
# {'Dalc', 'famrel', 'Pstatus', 'studytime', 'G3'}
#
#
# - Active trails from node 'famrel' given that 'Dalc' is observed:
#
# {'famrel', 'Pstatus'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'Dalc':
#
# {'Dalc', 'famrel', 'Pstatus', 'studytime', 'G3'}
#
#
# - Active trails from node 'Dalc' given that 'studytime' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'freetime', 'Dalc', 'schoolsup', 'goout', 'Pstatus', 'Medu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'schoolsup':
#
# {'studytime', 'schoolsup', 'G3'}
#
#
# - Active trails from node 'schoolsup' given that 'studytime' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'freetime', 'Dalc', 'schoolsup', 'goout', 'Pstatus', 'Medu'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'studytime':
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'Pstatus', 'Dalc', 'schoolsup', 'goout', 'G3', 'Medu'}
#
#
# - Active trails from node 'studytime' given that 'G3' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'absences', 'Dalc', 'schoolsup', 'goout', 'sex', 'Pstatus', 'Medu', 'age'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'sex':
#
# {'sex', 'G3'}
#
#
# - Active trails from node 'sex' given that 'G3' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'absences', 'Dalc', 'schoolsup', 'goout', 'sex', 'Pstatus', 'Medu', 'age'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'age':
#
# {'age', 'G3'}
#
#
# - Active trails from node 'age' given that 'G3' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'absences', 'Dalc', 'schoolsup', 'goout', 'sex', 'Pstatus', 'Medu', 'age'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'G3':
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'absences', 'Pstatus', 'Dalc', 'schoolsup', 'goout', 'sex', 'G3', 'Medu', 'age'}
#
#
# - Active trails from node 'G3' given that 'studytime' is observed:
#
# {'sex', 'absences', 'age', 'G3'}
#
# -------------------------------------------------------
#
#
# - Active trails from node 'absences':
#
# {'absences', 'G3'}
#
#
# - Active trails from node 'absences' given that 'G3' is observed:
#
# {'activities', 'famrel', 'famsup', 'Fedu', 'studytime', 'freetime', 'absences', 'Dalc', 'schoolsup', 'goout', 'sex', 'Pstatus', 'Medu', 'age'}
#
# -------------------------------------------------------

# %% [markdown]
# In the previous code, we defined as `observed_nodes` all of the nodes that theoretically are supposed to make inactive the two-edge active trails and viceversa.
#
# As we said earlier:
#
# - with *v-structures* X $\rightarrow$ Z $\leftarrow$ Y, X and Y are independent (inactive two-edge trail) only if Z is <u>not</u> given;
#
#
# - with *causal trails* X $\rightarrow$ Z $\rightarrow$ Y, X and Y are independent (inactive two-edge trail) only if Z is given;
#
#
# - with *common parent trails* X $\leftarrow$ Z $\rightarrow$ Y, X and Y are independent (inactive two-edge trail) only if Z is given.
#
# Let's consider for example the *active trails* from `schoolsup` from which we can spot both *v-structures* and *causal trails* dependencies:
#
# 1. given that `studytime` is <u>not</u> observed, all of the *v-structures* from `schoolsup` are inactive and oppositely the *causal trail* `schoolsup` $\rightarrow$ `studytime` $\rightarrow$ `G3` is active, meaning that:
#
#
# **<center>If `studytime` is not given, the active nodes are<br><br>  {'studytime', 'G3', 'schoolsup'}</center>**
#
#
# 2. given that `studytime` is observed, all of the *v-structures* from `schoolsup` are active and the *causal trail* `schoolsup` $\rightarrow$ `studytime` $\rightarrow$ `G3` is not active anymore. Moreover, given that `famsup`, `freetime` and `famrel` are also not observed, we can consider also the dependencies:
#
#     - `Medu`/`Fedu` $\rightarrow$ `famsup`, which is active given that `famsup` is not observed;
#
#     - `goout` $\leftarrow$ `freetime` $\rightarrow$ `activities`, which is active given that `famsup` is not observed.
#
#     - `Pstatus` $\rightarrow$ `famrel` $\rightarrow$ `Dalc`, which is also active given that `famrel` is not observed.
#
# So in this case we can state that:
#
# **<center>If `studytime` is given, the active nodes are <br><br>{'freetime', 'famrel', 'famsup', 'Fedu', 'schoolsup', 'goout', 'activities', 'Dalc', 'Pstatus', 'Medu'}</center>**

# %% [markdown]
# #### D-separability
#
# Two sets of nodes **X**, **Y** are *d-separated* given **Z** if there is *no active trail* between any X ∈ **X** and Y ∈ **Y** given **Z**.
# <br>Considering the same starting node we used above, we expect that all of the nodes which are part of the active trail that contains `schoolsup`, are <u>not</u> *d-separated* and viceversa.
# In the following code, we verify whether `schoolsup` is *d-separated* from other nodes in the active trail and from nodes outside of the active trail.

# %%
#variables:
active_trail_nodes = ['schoolsup', 
                      'studytime', 
                      'G3']

inactive_trail_nodes = ['Medu', 
                        'Fedu', 
                        'famsup',
                        'freetime',
                        'goout',
                        'activities',
                        'Pstatus',
                        'famrel',
                        'Dalc',  
                        'sex', 
                        'age',  
                        'absences'
                       ]

#check if schoolsup and the rest of active trail nodes are d-connected:

bool_vect1 = []

for i in range(len(active_trail_nodes)):
    
    bool_vect1.append(model.is_dconnected('schoolsup', active_trail_nodes[i]))
    
#check if schoolsup and the inactive trail nodes are d-connected:

bool_vect2 = []

for i in range(len(inactive_trail_nodes)):
    
    bool_vect2.append(model.is_dconnected('schoolsup', inactive_trail_nodes[i]))
    

#prints:

if all(bool_vect1):
    print("The nodes in the active trail are all d-connected to 'schoolsup'\n")
    print('-'*60)
    
else:
    print("The nodes in the active trail are NOT all d-connected to 'schoolsup'\n")
    print('-'*60)

if not any(bool_vect2):
    print("\nThe nodes that are not part of the active trail are all d-separated from 'schoolsup'\n")
    print('-'*60)
    
else:
    print("the nodes that are not part of the active trail are NOT all d-separated from 'schoolsup'")
    print('-'*60)
# Out:
# The nodes in the active trail are all d-connected to 'schoolsup'
#
# ------------------------------------------------------------
#
# The nodes that are not part of the active trail are all d-separated from 'schoolsup'
#
# ------------------------------------------------------------

# %% [markdown]
# Now instead, let's consider only `schoolsup` $\rightarrow$ `studytime` $\rightarrow$ `G3`.
#
# As we said earlier, these nodes are all part of the active trail, but if `studytime` is observed, we expect that `schoolsup` is now *d-separated* from `G3`.

# %%
if not model.is_dconnected('schoolsup', 'G3', observed=['studytime']):
    print("\n'schoolsup' and 'G3' are d-separated, as we expected.")

else: 
    print("\n'schoolsup' and 'G3' are d-connected, contrarily from what we expected.")
# Out:
# 'schoolsup' and 'G3' are d-separated, as we expected.

# %% [markdown]
# ##### Local independencies
#
# Each node is conditionally independent of its nondescendants given its parents. For example, if we consider `famsup`, we have that given the parents `Medu` and `Fedu`, `famsup` is conditionally independent of all nodes except the descendant `studytime` and `G3`.

# %%
print(f"As we expected, we have:\n\n{model.local_independencies('famsup')}")
# Out:
# As we expected, we have:
#
# (famsup ⟂ activities, famrel, freetime, absences, Dalc, schoolsup, goout, sex, Pstatus, age | Medu, Fedu)

# %% [markdown]
# ##### Markov blanket
#
# Each node is conditionally independent of all others given its Markov blanket, which consists of the node's parents, children and children's parents. For example, the Markov blanket of `famsup`, should be composed by:
#
# - parent nodes: `Medu` and `Fedu`;
#
# - children nodes: `studytime`;
#
# - children's parent nodes: `schoolsup`, `goout`, `activities` and `Dalc`.
#
# Given the Markov blanket of `famsup`, we expect that `famsup` is conditionally independent of `freetime`, `Pstatus`, `famrel`, `sex`, `age` , `absences` and `G3`.

# %%
print("The Markov blanket of 'famsup' (green nodes) is:\n")
plt.figure(figsize=(12, 8))


nx.draw(model, 
        pos=pos, 
        nodelist = model.get_markov_blanket('famsup'), 
        node_color="green", 
        with_labels=True, 
        **options)

nx.draw(model, 
        pos=pos, 
        nodelist= (model.nodes() - model.get_markov_blanket('famsup')), 
        node_color="orange", 
        with_labels=True, 
        **options)

nx.draw(model, 
        pos=pos, 
        nodelist = ['famsup'], 
        node_color="lightgray", 
        with_labels=True, 
        **options)
# Out:
# The Markov blanket of 'famsup' (green nodes) is:

# %% [markdown]
# As expected, the Markov blanket of `famsup` is composed by the above green nodes. Given the green nodes, we have that `famsup` is conditionally independent of the yellow nodes.

# %% [markdown]
# ##### Irrelevant variables
#
# Given the query $P(X|E)$, we will say that a node $Y$ *is irrelevant to the query* if $Y \not\in AncestralTree(X)$ or if $Y$ is d-separated from $X$ by $E$.
# In particular, we define $AncestralTree(X)$ as $Ancestors(\{X\} \cup E)$.
#
# Due to the fact that in *pgmpy* there are no functions able to find irrelevant variables to a given query, we will graphically find the irrelevant variables and we will verify them by checking whether $Y$ is *d-connected* to $X$ by $E$.
# <br>
#
#
# Let's consider the query $P(studytime | Dalc)$:

# %%
print("The AncestralTree of 'studytime' (green nodes) is:\n")

plt.figure(figsize=(12, 8))

nx.draw(model, 
        pos=pos, 
        nodelist = model.get_ancestral_graph('studytime'), 
        node_color="green", 
        with_labels=True, 
        **options)

nx.draw(model, 
        pos=pos, 
        nodelist= (model.nodes() - model.get_ancestral_graph('studytime')), 
        node_color="orange", 
        with_labels=True, 
        **options)
# Out:
# The AncestralTree of 'studytime' (green nodes) is:

# %% [markdown]
# From the previous plot, we can graphically see that all of the yellow nodes are **irrelevant variables** to the given query. Now let's confirm this by checking whether the yellow variables and `studytime` are *d-separated* or not, given that `famsup` is observed.

# %%
print(model.is_dconnected('absences', 'studytime', observed='Dalc'))
print(model.is_dconnected('sex', 'studytime', observed='Dalc'))
print(model.is_dconnected('age', 'studytime', observed='Dalc'))
# Out:
# False
# False
# False

# %% [markdown]
# As we expected, the results are verified.

# %% [markdown]
# ## 4. Parameter Estimation
#
# <p id="parameter_estimation"></p>
#
# Since the bayesian network has been created successfully, we can now proceed estimating the *Conditional Probability Distributions* (**CPDs**).
#
# Parameter learning can be accomplished by using *pgmpy*'s `.fit()` method, which, given a model, a dataframe and an estimator, is able to
# compute the CPDs.
# The two most commonly used estimators are:
#
# - ***Maximum Likelihood Estimator*** (*MLE*), which exploits the relative frequencies of the variables occurrencies to compute the CPDs that maximises $P(data | model)$;
#
#
# - ***Bayesian Estimator***, which uses already existing prior conditional probability tables in order to compute the CPDs.
#
# We decided to use a Bayesian Estimator, because the dataset we are using comprehends well defined priors which contain relevant insight to the scope of this project work.
#
# Once the *CPDs* have been computed correctly, we can represent them in *Conditional Probability Distributions*.
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
#Initialize CPDs list:
model.cpds = []


#Estimante parameters:
model.fit(data = df_new,
          estimator = BayesianEstimator,
          prior_type = "BDeu")


#Verify integrity of the CPDs:
if model.check_model():
    print('The CPDs have been computed correctly.\n')
    
    #Represent CPDs in CPTs:
    for cpd in model.get_cpds():
        print(f"Conditional Probability Table of '{cpd.variable}':")
        print(cpd, '\n')
        
else:
    print('Parameter estimation failed to be consistent.\n')
# Out:
# The CPDs have been computed correctly.
#
# Conditional Probability Table of 'Medu':
# +---------+------------+
# | Medu(0) | 0.00953289 |
# +---------+------------+
# | Medu(1) | 0.193518   |
# +---------+------------+
# | Medu(2) | 0.276454   |
# +---------+------------+
# | Medu(3) | 0.227836   |
# +---------+------------+
# | Medu(4) | 0.29266    |
# +---------+------------+
#
# Conditional Probability Table of 'famsup':
# +-------------+---------------------+---------+---------+-----+--------------------+---------------------+
# | Fedu        | Fedu(0)             | Fedu(0) | Fedu(0) | ... | Fedu(4)            | Fedu(4)             |
# +-------------+---------------------+---------+---------+-----+--------------------+---------------------+
# | Medu        | Medu(0)             | Medu(1) | Medu(2) | ... | Medu(3)            | Medu(4)             |
# +-------------+---------------------+---------+---------+-----+--------------------+---------------------+
# | famsup(no)  | 0.08333333333333333 | 0.5     | 0.5     | ... | 0.3907766990291262 | 0.24273607748184023 |
# +-------------+---------------------+---------+---------+-----+--------------------+---------------------+
# | famsup(yes) | 0.9166666666666666  | 0.5     | 0.5     | ... | 0.6092233009708737 | 0.7572639225181598  |
# +-------------+---------------------+---------+---------+-----+--------------------+---------------------+
#
# Conditional Probability Table of 'Fedu':
# +---------+------------+
# | Fedu(0) | 0.00953289 |
# +---------+------------+
# | Fedu(1) | 0.244995   |
# +---------+------------+
# | Fedu(2) | 0.309819   |
# +---------+------------+
# | Fedu(3) | 0.221163   |
# +---------+------------+
# | Fedu(4) | 0.21449    |
# +---------+------------+
#
# Conditional Probability Table of 'freetime':
# +-------------+-----------+
# | freetime(1) | 0.0619638 |
# +-------------+-----------+
# | freetime(2) | 0.163966  |
# +-------------+-----------+
# | freetime(3) | 0.389895  |
# +-------------+-----------+
# | freetime(4) | 0.280267  |
# +-------------+-----------+
# | freetime(5) | 0.103908  |
# +-------------+-----------+
#
# Conditional Probability Table of 'goout':
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | freetime | freetime(1)         | freetime(2)         | ... | freetime(4)         | freetime(5)         |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | goout(1) | 0.15692307692307692 | 0.12906976744186047 | ... | 0.03129251700680272 | 0.09357798165137614 |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | goout(2) | 0.3723076923076923  | 0.3616279069767442  | ... | 0.1435374149659864  | 0.16697247706422016 |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | goout(3) | 0.3261538461538461  | 0.2744186046511628  | ... | 0.28979591836734697 | 0.08440366972477063 |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | goout(4) | 0.11076923076923077 | 0.14069767441860465 | ... | 0.354421768707483   | 0.18532110091743118 |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
# | goout(5) | 0.03384615384615385 | 0.0941860465116279  | ... | 0.18095238095238098 | 0.46972477064220186 |
# +----------+---------------------+---------------------+-----+---------------------+---------------------+
#
# Conditional Probability Table of 'activities':
# +-----------------+---------------------+-----+---------------------+--------------------+
# | freetime        | freetime(1)         | ... | freetime(4)         | freetime(5)        |
# +-----------------+---------------------+-----+---------------------+--------------------+
# | activities(no)  | 0.7461538461538462  | ... | 0.5017006802721088  | 0.3623853211009174 |
# +-----------------+---------------------+-----+---------------------+--------------------+
# | activities(yes) | 0.25384615384615383 | ... | 0.49829931972789115 | 0.6376146788990825 |
# +-----------------+---------------------+-----+---------------------+--------------------+
#
# Conditional Probability Table of 'Pstatus':
# +------------+----------+
# | Pstatus(A) | 0.117731 |
# +------------+----------+
# | Pstatus(T) | 0.882269 |
# +------------+----------+
#
# Conditional Probability Table of 'famrel':
# +-----------+---------------------+----------------------+
# | Pstatus   | Pstatus(A)          | Pstatus(T)           |
# +-----------+---------------------+----------------------+
# | famrel(1) | 0.06072874493927125 | 0.025391680172879523 |
# +-----------+---------------------+----------------------+
# | famrel(2) | 0.07692307692307693 | 0.041599135602377095 |
# +-----------+---------------------+----------------------+
# | famrel(3) | 0.1417004048582996  | 0.1647757968665586   |
# +-----------+---------------------+----------------------+
# | famrel(4) | 0.4331983805668016  | 0.49648838465694217  |
# +-----------+---------------------+----------------------+
# | famrel(5) | 0.2874493927125506  | 0.2717450027012426   |
# +-----------+---------------------+----------------------+
#
# Conditional Probability Table of 'Dalc':
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | famrel  | famrel(1)           | famrel(2)            | ... | famrel(4)            | famrel(5)            |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | Dalc(1) | 0.5548387096774194  | 0.5041666666666665   | ... | 0.6884990253411306   | 0.767247386759582    |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | Dalc(2) | 0.16774193548387098 | 0.3166666666666666   | ... | 0.20701754385964913  | 0.09825783972125438  |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | Dalc(3) | 0.13548387096774195 | 0.12916666666666665  | ... | 0.06276803118908382  | 0.07386759581881534  |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | Dalc(4) | 0.07096774193548389 | 0.004166666666666667 | ... | 0.019883040935672513 | 0.028571428571428574 |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
# | Dalc(5) | 0.07096774193548389 | 0.04583333333333333  | ... | 0.021832358674463936 | 0.03205574912891986  |
# +---------+---------------------+----------------------+-----+----------------------+----------------------+
#
# Conditional Probability Table of 'schoolsup':
# +----------------+----------+
# | schoolsup(no)  | 0.884175 |
# +----------------+----------+
# | schoolsup(yes) | 0.115825 |
# +----------------+----------+
#
# Conditional Probability Table of 'studytime':
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | Dalc         | Dalc(1)               | ... | Dalc(5)               | Dalc(5)               |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | activities   | activities(no)        | ... | activities(yes)       | activities(yes)       |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | famsup       | famsup(no)            | ... | famsup(yes)           | famsup(yes)           |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | goout        | goout(1)              | ... | goout(5)              | goout(5)              |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | schoolsup    | schoolsup(no)         | ... | schoolsup(no)         | schoolsup(yes)        |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | studytime(1) | 0.4993765586034913    | ... | 0.39925373134328357   | 0.9953416149068326    |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | studytime(2) | 0.39962593516209477   | ... | 0.39925373134328357   | 0.0015527950310559012 |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | studytime(3) | 0.10037406483790526   | ... | 0.0012437810945273632 | 0.0015527950310559012 |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
# | studytime(4) | 0.0006234413965087283 | ... | 0.20024875621890548   | 0.0015527950310559012 |
# +--------------+-----------------------+-----+-----------------------+-----------------------+
#
# Conditional Probability Table of 'sex':
# +--------+----------+
# | sex(F) | 0.565777 |
# +--------+----------+
# | sex(M) | 0.434223 |
# +--------+----------+
#
# Conditional Probability Table of 'G3':
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | absences              | absences(+30)       | ... | absences(21-30)     | absences(21-30)     |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | age                   | age(15-17)          | ... | age(20-22)          | age(20-22)          |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | sex                   | sex(F)              | ... | sex(M)              | sex(M)              |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | studytime             | studytime(1)        | ... | studytime(3)        | studytime(4)        |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Bom)               | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Excelente)         | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Mau)               | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Mediocre)          | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Mui bom distincao) | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Muito Bom)         | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
# | G3(Suficiente)        | 0.14285714285714285 | ... | 0.14285714285714285 | 0.14285714285714285 |
# +-----------------------+---------------------+-----+---------------------+---------------------+
#
# Conditional Probability Table of 'age':
# +------------+-----------+
# | age(15-17) | 0.718462  |
# +------------+-----------+
# | age(18-19) | 0.266603  |
# +------------+-----------+
# | age(20-22) | 0.0149349 |
# +------------+-----------+
#
# Conditional Probability Table of 'absences':
# +-----------------+------------+
# | absences(+30)   | 0.00691134 |
# +-----------------+------------+
# | absences(0-10)  | 0.886797   |
# +-----------------+------------+
# | absences(11-20) | 0.0888942  |
# +-----------------+------------+
# | absences(21-30) | 0.0173975  |
# +-----------------+------------+

# %% [markdown]
# ## 5. Inferences
# <p id="inferences"></p>
#
# Since the model has been created successfully and the CPDs have been computed correctly, we have finally generated a bayesian network that represents a complex *Joint Probability Function*, to which we can compute inferences that take into account all of the random variables and their possible instances.
#
# There are two types of bayesian inferences:
#
# 1. ***exact inference***, with which we analytically compute the CPDs over some arbitrarily choosen random variables;
#
#
# 2. ***approximate inference***, with which the CPDs are computed exploiting approximation techniques based on statistical sampling.
#
# <br>
# <img src="images/graph.png " width="210" align = "right"/>
#
# Also, in bayesian inferences there are different reasoning patterns:
#
#
#
# * ***predictive (or causal) reasoning***, when the inference flows from cause to effect, e.g. $P(Y | X_1)$.
# <br>
#
# * ***diagnostic (or evidential) reasoning***, when the inference flows from effect to cause, e.g. $P(X_1 | Y)$.
# <br>
#
# * ***intercausal reasoning***, when the inference flows from a cause to another, both with a common effect, e.g. $P(X_1 | X_2, Y)$ or $P(X_2 | X_1, Y)$.
#
#
# <br>
# In the following sections, we will see both exact and aproximate inference queries that are based on each of the above reasoning patterns.
#
# <a href = "#index"><b>*back to the top*</b></a>

# %% [markdown]
# <p id="index_inferences"></p>
#
# ##### Index of inferences:
# Exact Inference:
#
# - Causal:
#
#     1. <a href = "#grade_given_age_sex"><u>*$P(G3| Sex, Age)$*</u></a>
#
#     2. <a href = "#grade_given_studytime"><u>*$P(G3| Studytime)$*</u></a>
#
#     3. <a href = "#famsup_given_medu_fedu"><u>*$P(Famsup| Medu, Fedu)$*</u></a>
#
#     4. <a href = "#G3_given_dalc"><u>*$P(G3| Dalc)$*</u></a>
#
#     5. <a href = "#G3_given_studytime_activities"><u>*$P(G3| studytime, activities)$*</u></a>
#
#
# - Evidential:
#
#     6. <a href = "#studytime_given_G3"><u>*$P(Studytime| G3)$*</u></a>
#
#     7. <a href = "#absences_given_G3"><u>*$P(absences| G3)$*</u></a>
#
#
# - Intercausal:
#
#     8. <a href = "#sex_given_studytime_G3"><u>*$P(sex| G3, studytime)$*</u></a>
#
#     9. <a href = "#dalc_given_studytime_famsup"><u>*$P(Dalc| Studytime, famsup)$*</u></a>
#
#     10. <a href = "#dalc_given_studytime_goout"><u>*$P(Dalc| Studytime, goout)$*</u></a>
#
#
#  ------
#  <p id="index_app"></p>
#  Approximate Inference:
#
#
#  - Causal:
#
#     1. <a href = "#app_famsup_given_medu_fedu"><u>*$P(famsup| Medu, Fedu)$*</u></a>
#
# - Evidential:
#
#     6. <a href = "#app_studytime_given_G3"><u>*$P(Studytime| G3)$*</u></a>
#
#
# - Intercausal:
#
#     9. <a href = "#app_absences_given_G3_studytime"><u>*$P(Dalc| Studytime, goout)$*</u></a>

# %% [markdown]
# ### 5.1. Exact Inferences
#
# <p id="exact_inferences"></p>
#
#
# In general, exact inference can be done by *enumeration* or by *variable elimination*. However, inference by enumeration typically is computationally slow, that is the reason why we have choosen the **Variable Elimination algorithm**.
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
from pgmpy.inference import VariableElimination

infer = VariableElimination(model)

# %% [markdown]
# In order to represent graphically each query, we defined the following python function:

# %%
def plot_pdf(rows, cols, titles, pdf_legends, figsize, x_ticklabels, diz):
    
    #define subplots structure:
    f, ax = plt.subplots(rows, cols, figsize = figsize)    
    
    
    #define axis' labels and values:
    x_axis = np.arange(len(x_ticklabels))
   
    y_labels = []  
    max_height = []
    
    for k in range(len(diz)):
        y_labels.append(diz[k].values())
        
        max_height.append(max(list(diz[k].values())))
    
    max_height = max(max_height)+10                      
    #iteratively create subplots:
    index = 0
    
    if rows == 1:
        for i in range(cols):
            ax[i].bar(x_axis, y_labels[index], tick_label = x_ticklabels, label = pdf_legends[index], width = 0.1)
            ax[i].set_ylim(top=max_height)
            ax[i].grid()
            ax[i].legend()
            ax[i].set_title(titles[index])
            
            index = index + 1
            
    else:        
        for i in range(cols):
            for j in range(rows):
                ax[i,j].bar(x_axis, y_labels[index], tick_label = x_ticklabels, label = pdf_legends[index], width = 0.1)
                ax[i,j].set_ylim(top=max_height)
                ax[i,j].grid()
                ax[i,j].legend()
                ax[i,j].set_title(titles[index])

                index = index + 1
    
    plt.show()

# %% [markdown]
# ### 5.1.1. Causal Inference Queries

# %% [markdown]
# <p id="grade_given_age_sex"></p>
#
#
# * **What is the probability of each possible instance of <u>Grade</u> given the <u>Age</u> and <u>Sex</u> of the student?**
#
#
# $$
# \begin{align}
# P(G3| Sex= "M", Age= "15-17")\\
# P(G3| Sex= "F", Age= "15-17")
# \end{align}
# $$
#
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

print("** Age between 15 and 17:\n")


#Inferences:
q1_1 = infer.query(["G3"], evidence = {"sex": 'M',"age": '15-17'}, show_progress = False)
q1_2 = infer.query(["G3"], evidence = {"sex": 'F',"age": '15-17'}, show_progress = False)


#Print CPTs:
print(f"- Male students\n\n {q1_1}")
print(f"\n- Female students\n\n{q1_2}")



#------------Plotting the PDFs------------

#x axis ticklabels:
x_ticklabels = ["Mau",
                "Med", 
                "Suf",
                "Bom",
                "Muito Bom",
                "Exc",
                "Mui bom dist"]

#Setting y values of first dictionary:
diz1 = dict({"Bom": q1_1.values[0]*100,
             "Exc": q1_1.values[1]*100,
             "Mau": q1_1.values[2]*100,
             "Med": q1_1.values[3]*100,
             "Mui bom dist": q1_1.values[4]*100,
             "Muito Bom": q1_1.values[5]*100,
             "Suf": q1_1.values[6]*100
            })

#Reordering first dictionary:
diz1 = {k: diz1[k] for k in x_ticklabels}

#Setting y values of second dictionary:
diz2 = dict({"Bom": q1_2.values[0]*100,
             "Exc": q1_2.values[1]*100,
             "Mau": q1_2.values[2]*100,
             "Med": q1_2.values[3]*100,
             "Mui bom dist": q1_2.values[4]*100,
             "Muito Bom": q1_2.values[5]*100,
             "Suf": q1_2.values[6]*100
            })

#Reordering second dictionary:
diz2 = {k: diz2[k] for k in x_ticklabels}

#Variables to plot PDFs:
rows = 1
cols = 2
titles = ["Male Students", "Female Students"]
pdf_legends = ['age: 15-17', 'age: 15-17']
figsize = (15,7)
diz = [diz1, diz2]


#plot all the pdf:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# ** Age between 15 and 17:
#
# - Male students
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1720 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0503 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0510 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1239 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0088 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0873 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5067 |
# +-----------------------+-----------+
#
# - Female students
#
# +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1725 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0281 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0646 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1268 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0009 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0979 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5092 |
# +-----------------------+-----------+
#
# PDFs in percentage format:

# %% [markdown]
# $$
# \begin{align}
# P(G3| Sex= "M", Age= "20-22")\\
# P(G3| Sex= "F", Age= "20-22")
# \end{align}
# $$

# %%
#--------Inference CPT representations--------

print("** Age between 20 and 22:\n")


#Inferences:
q3_1 = infer.query(["G3"],evidence={"sex": 'M',"age": '20-22'}, show_progress = False)
q3_2 = infer.query(["G3"], evidence = {"sex": 'F',"age": '20-22'}, show_progress = False)


#Print CPTs:
print(f"- Male students\n\n {q3_1}")
print(f"\n- Female students\n\n{q3_2}")



#------------Plotting the PDFs------------

#x axis ticklabels:
x_ticklabels = ["Mau",
                "Med", 
                "Suf",
                "Bom",
                "Muito Bom",
                "Exc",
                "Mui bom dist"]

#Setting y values of first dictionary:
diz1 = dict({"Bom": q3_1.values[0]*100,
             "Exc": q3_1.values[1]*100,
             "Mau": q3_1.values[2]*100,
             "Med": q3_1.values[3]*100,
             "Mui bom dist": q3_1.values[4]*100,
             "Muito Bom": q3_1.values[5]*100,
             "Suf": q3_1.values[6]*100
            })

#Reordering first dictionary:
diz1 = {k: diz1[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz2 = dict({"Bom": q3_2.values[0]*100,
             "Exc": q3_2.values[1]*100,
             "Mau": q3_2.values[2]*100,
             "Med": q3_2.values[3]*100,
             "Mui bom dist": q3_2.values[4]*100,
             "Muito Bom": q3_2.values[5]*100,
             "Suf": q3_2.values[6]*100
            })

#Reordering second dictionary:
diz2 = {k: diz2[k] for k in x_ticklabels}

#Variables to plot PDFs:
rows = 1
cols = 2
titles = ["Male Students", "Female Students"]
pdf_legends = ['age: 20-22', 'age: 20-22']
figsize = (15,7)
diz = [diz1, diz2]


#plot all the pdf:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# ** Age between 20 and 22:
#
# - Male students
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1807 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.1807 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.1048 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.2287 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0963 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0963 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.1125 |
# +-----------------------+-----------+
#
# - Female students
#
# +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1298 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0283 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0283 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.0283 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0283 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0283 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.7284 |
# +-----------------------+-----------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="grade_given_studytime"></p>
#
# * **What is the probability of all instances of <u>final grade</u> given the amount of <u>studytime</u>?**
#
# $$
# \begin{align}
# P(G3| Studytime=1)\\
# P(G3| Studytime=2)\\
# P(G3| Studytime=3)\\
# P(G3| Studytime=4)\\
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q3_1 = infer.query(["G3"],evidence={"studytime": 1}, show_progress = False)
q3_2 = infer.query(["G3"], evidence = {"studytime": 2}, show_progress = False)
q3_3 = infer.query(["G3"],evidence={"studytime": 3}, show_progress = False)
q3_4 = infer.query(["G3"], evidence = {"studytime": 4}, show_progress = False)

#Print CPTs:
print(f"- CPT of studytime = 1:\n\n {q3_1}")
print(f"\n- CPT of studytime = 2:\n\n{q3_2}")
print(f"\n- CPT of studytime = 3:\n\n{q3_3}")
print(f"\n- CPT of studytime = 4:\n\n{q3_4}")



#------------Plotting the PDFs------------

#x axis ticklabels:
x_ticklabels = ["Mau",
                "Med", 
                "Suf",
                "Bom",
                "Muito Bom",
                "Exc",
                "Mui bom dist"]

#Setting y values of first dictionary:
diz1 = dict({"Bom": q3_1.values[0]*100,
             "Exc": q3_1.values[1]*100,
             "Mau": q3_1.values[2]*100,
             "Med": q3_1.values[3]*100,
             "Mui bom dist": q3_1.values[4]*100,
             "Muito Bom": q3_1.values[5]*100,
             "Suf": q3_1.values[6]*100
            })

#Reordering first dictionary:
diz1 = {k: diz1[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz2 = dict({"Bom": q3_2.values[0]*100,
             "Exc": q3_2.values[1]*100,
             "Mau": q3_2.values[2]*100,
             "Med": q3_2.values[3]*100,
             "Mui bom dist": q3_2.values[4]*100,
             "Muito Bom": q3_2.values[5]*100,
             "Suf": q3_2.values[6]*100
            })

#Reordering second dictionary:
diz2 = {k: diz2[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz3 = dict({"Bom": q3_3.values[0]*100,
             "Exc": q3_3.values[1]*100,
             "Mau": q3_3.values[2]*100,
             "Med": q3_3.values[3]*100,
             "Mui bom dist": q3_3.values[4]*100,
             "Muito Bom": q3_3.values[5]*100,
             "Suf": q3_3.values[6]*100
            })

#Reordering second dictionary:
diz3 = {k: diz3[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz4 = dict({"Bom": q3_4.values[0]*100,
             "Exc": q3_4.values[1]*100,
             "Mau": q3_4.values[2]*100,
             "Med": q3_4.values[3]*100,
             "Mui bom dist": q3_4.values[4]*100,
             "Muito Bom": q3_4.values[5]*100,
             "Suf": q3_4.values[6]*100
            })

#Reordering second dictionary:
diz4 = {k: diz4[k] for k in x_ticklabels}

#Variables to plot PDFs:
rows = 2
cols = 2
titles = [" ", " ", " ", " "]
pdf_legends = ['studytime = 1', 'studytime = 2', 'studytime = 3', 'studytime = 4']
figsize = (15,7)
diz = [diz1, diz2, diz3, diz4]


#plot all the pdf:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - CPT of studytime = 1:
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1199 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0212 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0989 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1601 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0018 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0519 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5462 |
# +-----------------------+-----------+
#
# - CPT of studytime = 2:
#
# +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1595 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0288 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0777 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1338 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0026 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0956 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5020 |
# +-----------------------+-----------+
#
# - CPT of studytime = 3:
#
# +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.2724 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0565 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0347 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1038 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0092 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.1334 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.3900 |
# +-----------------------+-----------+
#
# - CPT of studytime = 4:
#
# +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1394 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0967 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.1003 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.0860 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0268 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.1089 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.4418 |
# +-----------------------+-----------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="famsup_given_medu_fedu"></p>
#
# * **What is the chance that a student receives <u>family support</u> given the <u>parental level of education</u>?**
#
# $$
# \begin{align}
# P(Famsup| Medu= 1, Fedu= 1)\\
# P(Famsup| Medu= 4, Fedu= 4)\\
# P(Famsup| Medu= 4, Fedu= 1)\\
# P(Famsup| Medu= 1, Fedu= 4)\\
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q4_1 = infer.query(["famsup"], evidence={"Medu": 1,"Fedu": 1}, show_progress = False)
q4_2 = infer.query(["famsup"], evidence={"Medu": 4,"Fedu": 4}, show_progress = False) 
q4_3 = infer.query(["famsup"], evidence={"Medu": 4,"Fedu": 1}, show_progress = False) 
q4_4 = infer.query(["famsup"], evidence={"Medu": 1,"Fedu": 4}, show_progress = False)


#Print CPTs:
print(f"- Case 1: \tMedu = 1 & Fedu = 1\n\n {q4_1}")
print(f"\n\n- Case 2: \tMedu = 4 & Fedu = 4\n\n {q4_2}")
print(f"\n\n- Case 3: \tMedu = 4 & Fedu = 1\n\n {q4_3}")
print(f"\n\n- Case 4: \tMedu = 1 & Fedu = 4\n\n {q4_4}")



#------------Plotting the PDFs------------


#Setting y values of first dictionary:
diz1 = dict({" ": 0,
             "no": q4_1.values[0]*100,
             "yes": q4_1.values[1]*100,
             "": 0
            })


#Setting y values of second dictionary:
diz2 = dict({" ": 0,
             "no": q4_2.values[0]*100,
             "yes": q4_2.values[1]*100,
             "": 0
            })


#Setting y values of third dictionary:
diz3 = dict({" ": 0,
             "no": q4_3.values[0]*100,
             "yes": q4_3.values[1]*100,
             "": 0
            })


#Setting y values of fourth dictionary:
diz4 = dict({" ": 0,
             "no": q4_4.values[0]*100,
             "yes": q4_4.values[1]*100,
             "": 0
            })

#Variables to plot PDFs:
rows = 2
cols = 2
titles = ['Parents with very low education level',
          'Parents with very high education level',
          'Parents with unbalanced education level (Medu >>Fedu)',
          'Parents with unbalanced education level (Fedu >>Medu)'
         ]

pdf_legends = ['Medu = 1 & Fedu = 1', 
              'Medu = 4 & Fedu = 4', 
              'Medu = 4 & Fedu = 1', 
              'Medu = 1 & Fedu = 4',]

figsize = (15,10)
diz = [diz1, diz2, diz3, diz4]
x_ticklabels = [" ",
                "No", 
                "Yes",
                " "
               ]


#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	Medu = 1 & Fedu = 1
#
#  +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.4187 |
# +-------------+---------------+
# | famsup(yes) |        0.5813 |
# +-------------+---------------+
#
#
# - Case 2: 	Medu = 4 & Fedu = 4
#
#  +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2427 |
# +-------------+---------------+
# | famsup(yes) |        0.7573 |
# +-------------+---------------+
#
#
# - Case 3: 	Medu = 4 & Fedu = 1
#
#  +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.5543 |
# +-------------+---------------+
# | famsup(yes) |        0.4457 |
# +-------------+---------------+
#
#
# - Case 4: 	Medu = 1 & Fedu = 4
#
#  +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.3438 |
# +-------------+---------------+
# | famsup(yes) |        0.6562 |
# +-------------+---------------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="G3_given_dalc"></p>
#
# * **What is the probabilities distribution of <u>G3</u> given <u>Dalc</u>?**
#
#
# $$
# \begin{align}
# P(G3| Dalc=1)\\
# P(G3| Dalc=3)\\
# P(G3| Dalc=5)\\
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q4_1 = infer.query(["G3"], evidence={"Dalc": 1}, show_progress = False) 
q4_2 = infer.query(["G3"], evidence={"Dalc": 3}, show_progress = False)
q4_3 = infer.query(["G3"], evidence={"Dalc": 5}, show_progress = False) 


#Print CPTs:
print(f"- Case 1: \tDalc = 1 \n\n {q4_1}")
print(f"\n\n- Case 2: \tDalc = 3 \n\n {q4_2}")
print(f"\n\n- Case 3: \tDalc = 5 \n\n {q4_3}")


#------------Plotting the PDFs------------

x_ticklabels = ["Mau",
                "Med", 
                "Suf",
                "Bom",
                "Muito Bom",
                "Exc",
                "Mui bom dist"
               ]

#Setting y values of first dictionary:
diz1 = dict({"Bom": q4_1.values[0]*100,
             "Exc": q4_1.values[1]*100,
             "Mau": q4_1.values[2]*100,
             "Med": q4_1.values[3]*100,
             "Mui bom dist": q4_1.values[4]*100,
             "Muito Bom": q4_1.values[5]*100,
             "Suf": q4_1.values[6]*100
            })

#Reordering second dictionary:
diz1 = {k: diz1[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz2 = dict({"Bom": q4_2.values[0]*100,
             "Exc": q4_2.values[1]*100,
             "Mau": q4_2.values[2]*100,
             "Med": q4_2.values[3]*100,
             "Mui bom dist": q4_2.values[4]*100,
             "Muito Bom": q4_2.values[5]*100,
             "Suf": q4_2.values[6]*100
            })

#Reordering second dictionary:
diz2 = {k: diz2[k] for k in x_ticklabels}


#Setting y values of third dictionary:
diz3 = dict({"Bom": q4_3.values[0]*100,
             "Exc": q4_3.values[1]*100,
             "Mau": q4_3.values[2]*100,
             "Med": q4_3.values[3]*100,
             "Mui bom dist": q4_3.values[4]*100,
             "Muito Bom": q4_3.values[5]*100,
             "Suf": q4_3.values[6]*100
            })

#Reordering second dictionary:
diz3 = {k: diz3[k] for k in x_ticklabels}


#Variables to plot PDFs:
rows = 1
cols = 3
titles = ['workday alcohol consumption : 1',
          'workday alcohol consumption : 3',
          'workday alcohol consumption : 5'
         ]

pdf_legends = ['Dalc = 1', 
               'Dalc = 3', 
               'Dalc = 5', 
              ]

figsize = (20,10)
diz = [diz1, diz2, diz3]


#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	Dalc = 1
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1682 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0362 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0769 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1320 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0051 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0923 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.4894 |
# +-----------------------+-----------+
#
#
# - Case 2: 	Dalc = 3
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1470 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0331 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0869 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1405 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0048 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0777 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5100 |
# +-----------------------+-----------+
#
#
# - Case 3: 	Dalc = 5
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1590 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0429 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0829 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1299 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0078 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0881 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.4895 |
# +-----------------------+-----------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="G3_given_studytime_activities"></p>
#
# * **What is the probability distribution of <u>G3</u> given <u>studytime</u> and <u>activities</u>?**
#
#
#
# $$
# \begin{align}
# P(G3| studytime=1, activities= "yes")\\
# P(G3| studytime=2, activities= "yes")\\
# P(G3| studytime=4, activities= "no")
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q4_1 = infer.query(["G3"], evidence={"studytime": 1,"activities":"yes"}, show_progress = False) 
q4_2 = infer.query(["G3"], evidence={"studytime": 2,"activities":"yes"}, show_progress = False)
q4_3 = infer.query(["G3"], evidence={"studytime": 4,"activities":"no"}, show_progress = False)



#Print CPTs:
print(f"- Case 1: \t studytime = 1, activities= yes \n\n {q4_1}")
print(f"\n\n- Case 2: \t studytime = 2, activities= yes \n\n {q4_2}")
print(f"\n\n- Case 2: \t studytime = 4, activities= no \n\n {q4_3}")



#------------Plotting the PDFs------------
x_ticklabels = ["Mau",
                "Med", 
                "Suf",
                "Bom",
                "Muito Bom",
                "Exc",
                "Mui bom dist"
               ]

#Setting y values of first dictionary:
diz1 = dict({"Bom": q4_1.values[0]*100,
             "Exc": q4_1.values[1]*100,
             "Mau": q4_1.values[2]*100,
             "Med": q4_1.values[3]*100,
             "Mui bom dist": q4_1.values[4]*100,
             "Muito Bom": q4_1.values[5]*100,
             "Suf": q4_1.values[6]*100
            })

#Reordering second dictionary:
diz1 = {k: diz1[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz2 = dict({"Bom": q4_2.values[0]*100,
             "Exc": q4_2.values[1]*100,
             "Mau": q4_2.values[2]*100,
             "Med": q4_2.values[3]*100,
             "Mui bom dist": q4_2.values[4]*100,
             "Muito Bom": q4_2.values[5]*100,
             "Suf": q4_2.values[6]*100
            })

#Reordering second dictionary:
diz2 = {k: diz2[k] for k in x_ticklabels}

#Setting y values of second dictionary:
diz3 = dict({"Bom": q4_3.values[0]*100,
             "Exc": q4_3.values[1]*100,
             "Mau": q4_3.values[2]*100,
             "Med": q4_3.values[3]*100,
             "Mui bom dist": q4_3.values[4]*100,
             "Muito Bom": q4_3.values[5]*100,
             "Suf": q4_3.values[6]*100
            })

#Reordering second dictionary:
diz3 = {k: diz3[k] for k in x_ticklabels}


#Variables to plot PDFs:
rows = 1
cols = 3
titles = ['Low studtytime and activities',
          'Intermediate studtytime and activities',
          'High studtytime and no activities'
         ]

pdf_legends = ['studytime = 1, activities= yes',
               'studytime = 2, activities= yes',
               'studytime = 4, activities= no'
              ]

figsize = (20,10)

diz = [diz1, diz2,diz3]



#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	 studytime = 1, activities= yes
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1199 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0212 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0989 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1601 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0018 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0519 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5462 |
# +-----------------------+-----------+
#
#
# - Case 2: 	 studytime = 2, activities= yes
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1595 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0288 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.0777 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.1338 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0026 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.0956 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.5020 |
# +-----------------------+-----------+
#
#
# - Case 2: 	 studytime = 4, activities= no
#
#  +-----------------------+-----------+
# | G3                    |   phi(G3) |
# +=======================+===========+
# | G3(Bom)               |    0.1394 |
# +-----------------------+-----------+
# | G3(Excelente)         |    0.0967 |
# +-----------------------+-----------+
# | G3(Mau)               |    0.1003 |
# +-----------------------+-----------+
# | G3(Mediocre)          |    0.0860 |
# +-----------------------+-----------+
# | G3(Mui bom distincao) |    0.0268 |
# +-----------------------+-----------+
# | G3(Muito Bom)         |    0.1089 |
# +-----------------------+-----------+
# | G3(Suficiente)        |    0.4418 |
# +-----------------------+-----------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="studytime_given_G3"></p>
#
# ### 5.1.2. Evidential Inference Queries
#
# * **What is a student's <u>studytime</u> given his <u>final grade</u>?**
#
# $$
# \begin{align}
# P(Studytime| G3="Mau")\\
# P(Studytime| G3="Suficiente")\\
# P(Studytime| G3="Muito\ Bom")\\
# P(Studytime| G3="Mui\ bom\ distincao")
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------


#Inferences:
q5_1 = infer.query(["studytime"],evidence={"G3": "Mau"}, show_progress = False)
q5_2 = infer.query(["studytime"],evidence={"G3": "Suficiente"}, show_progress = False)
q5_3 = infer.query(["studytime"],evidence={"G3": "Muito Bom"}, show_progress = False)
q5_4 = infer.query(["studytime"],evidence={"G3": "Mui bom distincao"}, show_progress = False)


#Print CPTs:
print(f"- Case 1: \tFinal Grade = 'Mau'\n\n {q5_1}")
print(f"\n\n- Case 2: \tFinal Grade = 'Suficiente'\n\n {q5_2}")
print(f"\n\n- Case 3: \tFinal Grade = 'Muito bom'\n\n {q5_3}")
print(f"\n\n- Case 4: \tFinal Grade = 'Mui bom distincao'\n\n {q5_4}")



#------------Plotting the PDFs------------


#Setting y values of first dictionary:
diz1 = dict({1: q5_1.values[0]*100,
             2: q5_1.values[1]*100,
             3: q5_1.values[2]*100,
             4: q5_1.values[3]*100
            })


#Setting y values of second dictionary:
diz2 = dict({1: q5_2.values[0]*100,
             2: q5_2.values[1]*100,
             3: q5_2.values[2]*100,
             4: q5_2.values[3]*100
            })


#Setting y values of third dictionary:
diz3 = dict({1: q5_3.values[0]*100,
             2: q5_3.values[1]*100,
             3: q5_3.values[2]*100,
             4: q5_3.values[3]*100
            })


#Setting y values of fourth dictionary:
diz4 = dict({1: q5_4.values[0]*100,
             2: q5_4.values[1]*100,
             3: q5_4.values[2]*100,
             4: q5_4.values[3]*100
            })

#Variables to plot PDFs:
rows = 2
cols = 2
titles = ['Studytime having obtained "Mau"',
          'Studytime having obtained "Suficiente"',
          'Studytime having obtained "Muito Bom"',
          'Studytime having obtained "Mui bom distincao'
         ]

pdf_legends = ['G3 = "Mau"',
               'G3 = "Suficiente"',
               'G3 = "Muito Bom"',
               'G3 = "Mui bom distincao"']

figsize = (15,10)
diz = [diz1, diz2, diz3, diz4]
x_ticklabels = [1,
                2,
                3,
                4
               ]


#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	Final Grade = 'Mau'
#
#  +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3688 |
# +--------------+------------------+
# | studytime(2) |           0.4671 |
# +--------------+------------------+
# | studytime(3) |           0.0778 |
# +--------------+------------------+
# | studytime(4) |           0.0862 |
# +--------------+------------------+
#
#
# - Case 2: 	Final Grade = 'Suficiente'
#
#  +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3227 |
# +--------------+------------------+
# | studytime(2) |           0.4785 |
# +--------------+------------------+
# | studytime(3) |           0.1387 |
# +--------------+------------------+
# | studytime(4) |           0.0601 |
# +--------------+------------------+
#
#
# - Case 3: 	Final Grade = 'Muito bom'
#
#  +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.1666 |
# +--------------+------------------+
# | studytime(2) |           0.4950 |
# +--------------+------------------+
# | studytime(3) |           0.2578 |
# +--------------+------------------+
# | studytime(4) |           0.0805 |
# +--------------+------------------+
#
#
# - Case 4: 	Final Grade = 'Mui bom distincao'
#
#  +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.0993 |
# +--------------+------------------+
# | studytime(2) |           0.2395 |
# +--------------+------------------+
# | studytime(3) |           0.3117 |
# +--------------+------------------+
# | studytime(4) |           0.3495 |
# +--------------+------------------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="absences_given_G3"></p>
#
# * **What is the probability distribution of <u>absences</u> given his <u>final grade (G3)</u>?**
#
# $$
# \begin{align}
# P(absences| G3="Mau")\\
# P(absences| G3="Suficiente")\\
# P(absences| G3="Bom")
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q6_1 = infer.query(["absences"], evidence={"G3": "Mau"}, show_progress = False) 
q6_2 = infer.query(["absences"], evidence={"G3": "Suficiente"}, show_progress = False)
q6_3 = infer.query(["absences"], evidence={"G3": "Bom"}, show_progress = False) 


#Print CPTs:
print(f"- Case 1: \tG3 = Mau \n\n {q6_1}")
print(f"\n\n- Case 2: \tG3 = Suficiente \n\n {q6_2}")
print(f"\n\n- Case 3: \tG3 = Bom \n\n {q6_3}")




#------------Plotting the PDFs------------

x_ticklabels = ["0-10",
                "11-20",
                "21-30",
                "+30"]

#Setting y values of first dictionary:
diz1 = dict({"+30": q6_1.values[0]*100,
             "0-10": q6_1.values[1]*100,
             "11-20": q6_1.values[2]*100,
             "21-30": q6_1.values[3]*100
            })

diz1 = {k: diz1[k] for k in x_ticklabels}


#Setting y values of second dictionary:
diz2 = dict({"+30": q6_2.values[0]*100,
             "0-10": q6_2.values[1]*100,
             "11-20": q6_2.values[2]*100,
             "21-30": q6_2.values[3]*100
            })

diz2 = {k: diz2[k] for k in x_ticklabels}


#Setting y values of third dictionary:
diz3 = dict({"+30": q6_3.values[0]*100,
             "0-10": q6_3.values[1]*100,
             "11-20": q6_3.values[2]*100,
             "21-30": q6_3.values[3]*100
            })

diz3 = {k: diz3[k] for k in x_ticklabels}


#Variables to plot PDFs:
rows = 1
cols = 3
titles = ['Absences having obtained "Mau"',
          'Absences having obtained "Suficiente"',
          'Absences having obtained "Bom"'
         ]

pdf_legends = ['G3 = Mau',
               'G3 = Suficiente',
               'G3 = Bom' 
              ]

figsize = (15,10)
diz = [diz1, diz2, diz3]

#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	G3 = Mau
#
#  +-----------------+-----------------+
# | absences        |   phi(absences) |
# +=================+=================+
# | absences(+30)   |          0.0087 |
# +-----------------+-----------------+
# | absences(0-10)  |          0.8475 |
# +-----------------+-----------------+
# | absences(11-20) |          0.1064 |
# +-----------------+-----------------+
# | absences(21-30) |          0.0373 |
# +-----------------+-----------------+
#
#
# - Case 2: 	G3 = Suficiente
#
#  +-----------------+-----------------+
# | absences        |   phi(absences) |
# +=================+=================+
# | absences(+30)   |          0.0026 |
# +-----------------+-----------------+
# | absences(0-10)  |          0.9019 |
# +-----------------+-----------------+
# | absences(11-20) |          0.0868 |
# +-----------------+-----------------+
# | absences(21-30) |          0.0086 |
# +-----------------+-----------------+
#
#
# - Case 3: 	G3 = Bom
#
#  +-----------------+-----------------+
# | absences        |   phi(absences) |
# +=================+=================+
# | absences(+30)   |          0.0067 |
# +-----------------+-----------------+
# | absences(0-10)  |          0.9281 |
# +-----------------+-----------------+
# | absences(11-20) |          0.0588 |
# +-----------------+-----------------+
# | absences(21-30) |          0.0065 |
# +-----------------+-----------------+
#
# PDFs in percentage format:

# %% [markdown]
# ### 5.1.3. Intercausal Inference Queries

# %% [markdown]
# <p id="sex_given_studytime_G3"></p>
#
# * **What is the probability distribution of the <u>sex</u> given the <u>studytime</u> and the <u>final grade</u>?**
#
#
# $$
# \begin{align}
# P(sex| G3= "Suficiente", studytime= 1)\\
# P(sex| G3= "Suficiente", studytime= 4)\\
# P(sex| G3= "Excelente",  studytime= 1)\\
# P(sex| G3= "Excelente",  studytime= 4)
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q7_1 = infer.query(["sex"], evidence={"G3": 'Suficiente', "studytime": 1}, show_progress = False)
q7_2 = infer.query(["sex"], evidence={"G3": 'Suficiente', "studytime": 4}, show_progress = False)
q7_3 = infer.query(["sex"], evidence={"G3": 'Excelente', "studytime": 1}, show_progress = False)
q7_4 = infer.query(["sex"], evidence={"G3": 'Excelente', "studytime": 4}, show_progress = False)


#Print CPTs:
print(f"- Case 1: \tG3 = 'Suficiente' & studytime = 1\n\n {q7_1}")
print(f"\n\n- Case 2: \tG3 = 'Suficiente' & studytime = 4\n\n {q7_2}")
print(f"\n\n- Case 3: \tG3 = 'Excelente' & studytime = 1\n\n {q7_3}")
print(f"\n\n- Case 4: \tG3 = 'Excelente' & studytime = 4\n\n {q7_4}")


# 0: F , 1: M;

#------------Plotting the PDFs------------

#x axis tick labels:
x_ticklabels = ["",
                "F",
                "M",
                ""
               ]

#Setting y values of first dictionary:
diz1 = dict({"": 0,
             "F": q7_1.values[0]*100,
             "M" : q7_1.values[1]*100,
             " ": 0
            })

#Reordering first dictionary:
#diz1 = {k: diz1[k] for k in x_ticklabels}

#Setting y values of second dictionary:
diz2 = dict({"": 0,
            "F" : q7_2.values[0]*100,
             "M" : q7_2.values[1]*100,
             " ": 0
            })

#Setting y values of third dictionary:
diz3 = dict({"": 0,
             "F" : q7_3.values[0]*100,
             "M" : q7_3.values[1]*100,
             " ": 0
             })


#Setting y values of fourth dictionary:
diz4 = dict({"": 0,
             "F" : q7_4.values[0]*100,
             "M" : q7_4.values[1]*100,
             " ": 0
            })
            

#Variables to plot PDFs:
rows = 2
cols = 2
titles = [' ',
          ' ',
          ' ',
          ' '
         ]

pdf_legends = ["G3 = 'Suficiente' & studytime = 1",
               "G3 = 'Suficiente' & studytime = 4",
               "G3 = 'Excelente' & studytime = 1",
               "G3 = 'Excelente' & studytime = 4"
              ]

figsize = (15,10)
diz = [diz1, diz2, diz3, diz4]

#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	G3 = 'Suficiente' & studytime = 1
#
#  +--------+------------+
# | sex    |   phi(sex) |
# +========+============+
# | sex(F) |     0.6015 |
# +--------+------------+
# | sex(M) |     0.3985 |
# +--------+------------+
#
#
# - Case 2: 	G3 = 'Suficiente' & studytime = 4
#
#  +--------+------------+
# | sex    |   phi(sex) |
# +========+============+
# | sex(F) |     0.5186 |
# +--------+------------+
# | sex(M) |     0.4814 |
# +--------+------------+
#
#
# - Case 3: 	G3 = 'Excelente' & studytime = 1
#
#  +--------+------------+
# | sex    |   phi(sex) |
# +========+============+
# | sex(F) |     0.3756 |
# +--------+------------+
# | sex(M) |     0.6244 |
# +--------+------------+
#
#
# - Case 4: 	G3 = 'Excelente' & studytime = 4
#
#  +--------+------------+
# | sex    |   phi(sex) |
# +========+============+
# | sex(F) |     0.9153 |
# +--------+------------+
# | sex(M) |     0.0847 |
# +--------+------------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="dalc_given_studytime_famsup"></p>
#
# * **What is the probability distribution of <u>Dalc</u> given <u>studytime</u> and <u>famsup</u>?**
#
#
# $$
# \begin{align}
# P(Dalc| Studytime=1, famsup= "no")\\
# P(Dalc| Studytime=3, famsup= "yes")
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q6_2 = infer.query(["Dalc"], evidence={"studytime": 1,"famsup": 'no'}, show_progress = False)
q6_3 = infer.query(["Dalc"], evidence={"studytime": 3,"famsup": 'yes'}, show_progress = False)



#Print CPTs:

print(f"\n\n- Case 1: \tstudytime = 1 & famsup = 'no'\n\n {q6_2}")
print(f"\n\n- Case 2: \tstudytime = 3 & famsup = 'yes'\n\n {q6_3}")


#------------Plotting the PDFs------------



#Setting y values of second dictionary:
diz2 = dict({1: q6_2.values[0]*100,
             2: q6_2.values[1]*100,
             3: q6_2.values[2]*100,
             4: q6_2.values[3]*100,
             5: q6_2.values[4]*100,
            })


#Setting y values of third dictionary:
diz3 = dict({1: q6_3.values[0]*100,
             2: q6_3.values[1]*100,
             3: q6_3.values[2]*100,
             4: q6_3.values[3]*100,
             5: q6_3.values[4]*100,
            })



#Variables to plot PDFs:
rows = 1
cols = 2
titles = ['Workday alcohol consumption if low studytime and no family support',
          'Workday alcohol consumption if high studytime and family support'
         ]

pdf_legends = [
               'studytime = 1 & famsup = "no"',
               'studytime = 3 & famsup = "yes"',
              ]

figsize = (15,10)
diz = [ diz2, diz3]
x_ticklabels = [1,
                2,
                3,
                4,
                5
               ]


#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	studytime = 1 & famsup = 'no'
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.5587 |
# +---------+-------------+
# | Dalc(2) |      0.2604 |
# +---------+-------------+
# | Dalc(3) |      0.1237 |
# +---------+-------------+
# | Dalc(4) |      0.0340 |
# +---------+-------------+
# | Dalc(5) |      0.0232 |
# +---------+-------------+
#
#
# - Case 2: 	studytime = 3 & famsup = 'yes'
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.6787 |
# +---------+-------------+
# | Dalc(2) |      0.2383 |
# +---------+-------------+
# | Dalc(3) |      0.0422 |
# +---------+-------------+
# | Dalc(4) |      0.0223 |
# +---------+-------------+
# | Dalc(5) |      0.0185 |
# +---------+-------------+
#
# PDFs in percentage format:

# %% [markdown]
# <p id="dalc_given_studytime_goout"></p>
#
# * **What is the probability distribution of <u>Dalc</u> given <u>goout</u> and <u>studytime</u>?**
#
#
# $$
# \begin{align}
# P(Dalc| Studytime=1, goout= 1)\\
# P(Dalc| Studytime=4, goout= 1)\\
# P(Dalc| Studytime=1, goout= 4)\\
# P(Dalc| Studytime=4, goout= 4)
# \end{align}
# $$
#
# <a href = "#index_inferences"><u>*back to the index of inferences*</u></a>

# %%
#--------Inference CPT representations--------

#Inferences:
q4_1 = infer.query(["Dalc"], evidence={"studytime": 1, "goout": 1}, show_progress = False) 
q4_2 = infer.query(["Dalc"], evidence={"studytime": 4, "goout": 1}, show_progress = False)
q4_3 = infer.query(["Dalc"], evidence={"studytime": 1, "goout": 4}, show_progress = False) 
q4_4 = infer.query(["Dalc"], evidence={"studytime": 4, "goout": 4}, show_progress = False)


#Print CPTs:
print(f"- Case 1: \tstudytime: 1, goout: 1 \n\n {q4_1}")
print(f"\n\n- Case 2: \tstudytime: 4, goout: 1 \n\n {q4_2}")
print(f"\n\n- Case 3: \tstudytime: 1, goout: 4 \n\n {q4_3}")
print(f"\n\n- Case 3: \tstudytime: 4, goout: 4 \n\n {q4_4}")



#------------Plotting the PDFs------------


#Setting y values of first dictionary:
diz1 = dict({1: q4_1.values[0]*100,
             2: q4_1.values[1]*100,
             3: q4_1.values[2]*100,
             4: q4_1.values[3]*100,
             5: q4_1.values[4]*100,
            })


#Setting y values of second dictionary:
diz2 = dict({1: q4_2.values[0]*100,
             2: q4_2.values[1]*100,
             3: q4_2.values[2]*100,
             4: q4_2.values[3]*100,
             5: q4_2.values[4]*100,
            })


#Setting y values of third dictionary:
diz3 = dict({1: q4_3.values[0]*100,
             2: q4_3.values[1]*100,
             3: q4_3.values[2]*100,
             4: q4_3.values[3]*100,
             5: q4_3.values[4]*100,
            })

#Setting y values of third dictionary:
diz4 = dict({1: q4_4.values[0]*100,
             2: q4_4.values[1]*100,
             3: q4_4.values[2]*100,
             4: q4_4.values[3]*100,
             5: q4_4.values[4]*100,
            })


#Variables to plot PDFs:
rows = 2
cols = 2
titles = ['workday alcohol consumption : 1-1',
          'workday alcohol consumption : 4-1',
          'workday alcohol consumption : 1-4',
          'workday alcohol consumption : 4-4',
         ]

pdf_legends = ['stdt-gout = 1-1', 
               'stdt-gout= 4-1', 
               'stdt-gout= 1-4', 
               'stdt-gout= 4-4',
              ]

figsize = (15,10)
diz = [diz1, diz2, diz3,diz4]
x_ticklabels = [1,
                2,
                3,
                4,
                5]


#plot all the PDFs:
print("\nPDFs in percentage format:")
plot_pdf(rows = rows,
         cols = cols,
         titles = titles,
         pdf_legends = pdf_legends,
         figsize = figsize,
         x_ticklabels = x_ticklabels, 
         diz = diz)
# Out:
# - Case 1: 	studytime: 1, goout: 1
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.6672 |
# +---------+-------------+
# | Dalc(2) |      0.2286 |
# +---------+-------------+
# | Dalc(3) |      0.0698 |
# +---------+-------------+
# | Dalc(4) |      0.0172 |
# +---------+-------------+
# | Dalc(5) |      0.0172 |
# +---------+-------------+
#
#
# - Case 2: 	studytime: 4, goout: 1
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.4079 |
# +---------+-------------+
# | Dalc(2) |      0.2459 |
# +---------+-------------+
# | Dalc(3) |      0.1775 |
# +---------+-------------+
# | Dalc(4) |      0.0844 |
# +---------+-------------+
# | Dalc(5) |      0.0844 |
# +---------+-------------+
#
#
# - Case 3: 	studytime: 1, goout: 4
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.5285 |
# +---------+-------------+
# | Dalc(2) |      0.2365 |
# +---------+-------------+
# | Dalc(3) |      0.1455 |
# +---------+-------------+
# | Dalc(4) |      0.0295 |
# +---------+-------------+
# | Dalc(5) |      0.0600 |
# +---------+-------------+
#
#
# - Case 3: 	studytime: 4, goout: 4
#
#  +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7692 |
# +---------+-------------+
# | Dalc(2) |      0.0323 |
# +---------+-------------+
# | Dalc(3) |      0.0521 |
# +---------+-------------+
# | Dalc(4) |      0.0643 |
# +---------+-------------+
# | Dalc(5) |      0.0821 |
# +---------+-------------+
#
# PDFs in percentage format:

# %% [markdown]
# ### 5.2. Approximate Inferences
# <p id="approximate_inferences"></p>
#
# As we said above, exact inference is not the only way to compute inference queries, but sometimes it is advisable to compute an approximate result by considering only a restricted number of samples. As a matter of fact, the more samples we consider, the more accurate the result will be.
#
# In the following we will consider some of the previous queries, but this time we will compute the *Probability Density Functions* by using approximate inference with different number of samples (from 44 to 1045).
#
# What we want to demonstrate is how much the *pdf* changes based on the number of samples and, as we can see, the greater the samples the closer the pdf of the approximate inference is to the counterpart of the exact inference.
#
#
# <a href = "#index"><b>*back to the top*</b></a>

# %%
from pgmpy.inference import ApproxInference

approx_infer = ApproxInference(model)

samples_num = range(44, 1045, 100)    #[44, 144, 244,..., 944, 1044] (total of df_new's rows)

# %% [markdown]
# #### 5.2.1. Causal Inference Queries

# %% [markdown]
# <p id="app_famsup_given_medu_fedu"></p>
#
# * **What is the chance that a student receives <u>family support</u> given the <u>parental level of education</u>?**
#
# $$
# \begin{align}
# P(famsup| Medu=4, Fedu= 4)
# \end{align}
# $$
#
# <a href = "#index_app"><u>*back to the index of inferences*</u></a>

# %% [markdown]
# PDF (based on exact inference):
# - famsup(No): 0.2427
# - famsup(Yes): 0.7573

# %%
#variables:
query_variable = 'famsup'
evidence_variables = dict({"Medu": 4,"Fedu": 4})

#Approximate inference:
for i in samples_num:
    q = approx_infer.query(query_variable, 
                           i, 
                           evidence_variables,
                           show_progress = False)
    
    print(f'\n\nConditional Probability Table of variable "{query_variable}" given that "{evidence_variables}" are observed:')
    print(f'\nNumber of samples used to compute the approximate inference:\t{i}')
    print(f'\nConditional Probability Table:\n{q}')
# Out:
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	44
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2273 |
# +-------------+---------------+
# | famsup(yes) |        0.7727 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	144
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2222 |
# +-------------+---------------+
# | famsup(yes) |        0.7778 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	244
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2541 |
# +-------------+---------------+
# | famsup(yes) |        0.7459 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	344
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2558 |
# +-------------+---------------+
# | famsup(yes) |        0.7442 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	444
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2185 |
# +-------------+---------------+
# | famsup(yes) |        0.7815 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	544
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2776 |
# +-------------+---------------+
# | famsup(yes) |        0.7224 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	644
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2376 |
# +-------------+---------------+
# | famsup(yes) |        0.7624 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	744
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2325 |
# +-------------+---------------+
# | famsup(yes) |        0.7675 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	844
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2429 |
# +-------------+---------------+
# | famsup(yes) |        0.7571 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	944
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2383 |
# +-------------+---------------+
# | famsup(yes) |        0.7617 |
# +-------------+---------------+
#
#
# Conditional Probability Table of variable "famsup" given that "{'Medu': 4, 'Fedu': 4}" are observed:
#
# Number of samples used to compute the approximate inference:	1044
#
# Conditional Probability Table:
# +-------------+---------------+
# | famsup      |   phi(famsup) |
# +=============+===============+
# | famsup(no)  |        0.2519 |
# +-------------+---------------+
# | famsup(yes) |        0.7481 |
# +-------------+---------------+

# %% [markdown]
# ### 5.2.2. Intercausal Inference Queries

# %% [markdown]
# <p id="app_absences_given_G3_studytime"></p>
#
# * **What is the probability distribution of the <u>Dalc</u> given the <u>studytime</u> and the <u>goout</u>?**
#
# $$
# \begin{align}
# P(Dalc| Studytime=4, goout= 4)
# \end{align}
# $$
#
# PDF (based on exact inference):
# - Dalc(1): 0.7692
# - Dalc(2): 0.0323
# - Dalc(3): 0.0521
# - Dalc(4): 0.0643
# - Dalc(5): 0.0821
#
# <a href = "#index_app"><u>*back to the index of inferences*</u></a>

# %%
#variables:
query_variable = 'Dalc'
evidence_variables = dict({"goout": 4, "studytime": 4})

#Approximate inference:
for i in samples_num:
    q = approx_infer.query([query_variable], 
                            i, 
                            evidence_variables,
                           show_progress = False)
    
    print(f'Conditional Probability Table of variable "{query_variable}" given that "{evidence_variables}" are observed:')
    print(f'\n\tNumber of samples used to compute the approximate inference:\t{i}')
    print(f'\n\tConditional Probability Table:\n{q}')
# Out:
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	44
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7955 |
# +---------+-------------+
# | Dalc(2) |      0.0455 |
# +---------+-------------+
# | Dalc(4) |      0.0909 |
# +---------+-------------+
# | Dalc(5) |      0.0682 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	144
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7361 |
# +---------+-------------+
# | Dalc(2) |      0.0278 |
# +---------+-------------+
# | Dalc(3) |      0.0694 |
# +---------+-------------+
# | Dalc(4) |      0.0486 |
# +---------+-------------+
# | Dalc(5) |      0.1181 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	244
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7664 |
# +---------+-------------+
# | Dalc(2) |      0.0287 |
# +---------+-------------+
# | Dalc(3) |      0.0697 |
# +---------+-------------+
# | Dalc(4) |      0.0697 |
# +---------+-------------+
# | Dalc(5) |      0.0656 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	344
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7238 |
# +---------+-------------+
# | Dalc(2) |      0.0407 |
# +---------+-------------+
# | Dalc(3) |      0.0698 |
# +---------+-------------+
# | Dalc(4) |      0.0727 |
# +---------+-------------+
# | Dalc(5) |      0.0930 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	444
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7387 |
# +---------+-------------+
# | Dalc(2) |      0.0428 |
# +---------+-------------+
# | Dalc(3) |      0.0518 |
# +---------+-------------+
# | Dalc(4) |      0.0878 |
# +---------+-------------+
# | Dalc(5) |      0.0788 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	544
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7353 |
# +---------+-------------+
# | Dalc(2) |      0.0460 |
# +---------+-------------+
# | Dalc(3) |      0.0625 |
# +---------+-------------+
# | Dalc(4) |      0.0607 |
# +---------+-------------+
# | Dalc(5) |      0.0956 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	644
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.6988 |
# +---------+-------------+
# | Dalc(2) |      0.0637 |
# +---------+-------------+
# | Dalc(3) |      0.0512 |
# +---------+-------------+
# | Dalc(4) |      0.0854 |
# +---------+-------------+
# | Dalc(5) |      0.1009 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	744
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7151 |
# +---------+-------------+
# | Dalc(2) |      0.0618 |
# +---------+-------------+
# | Dalc(3) |      0.0591 |
# +---------+-------------+
# | Dalc(4) |      0.0820 |
# +---------+-------------+
# | Dalc(5) |      0.0820 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	844
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7512 |
# +---------+-------------+
# | Dalc(2) |      0.0438 |
# +---------+-------------+
# | Dalc(3) |      0.0569 |
# +---------+-------------+
# | Dalc(4) |      0.0652 |
# +---------+-------------+
# | Dalc(5) |      0.0829 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	944
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7076 |
# +---------+-------------+
# | Dalc(2) |      0.0614 |
# +---------+-------------+
# | Dalc(3) |      0.0689 |
# +---------+-------------+
# | Dalc(4) |      0.0636 |
# +---------+-------------+
# | Dalc(5) |      0.0985 |
# +---------+-------------+
# Conditional Probability Table of variable "Dalc" given that "{'goout': 4, 'studytime': 4}" are observed:
#
# 	Number of samples used to compute the approximate inference:	1044
#
# 	Conditional Probability Table:
# +---------+-------------+
# | Dalc    |   phi(Dalc) |
# +=========+=============+
# | Dalc(1) |      0.7490 |
# +---------+-------------+
# | Dalc(2) |      0.0479 |
# +---------+-------------+
# | Dalc(3) |      0.0536 |
# +---------+-------------+
# | Dalc(4) |      0.0709 |
# +---------+-------------+
# | Dalc(5) |      0.0785 |
# +---------+-------------+

# %% [markdown]
# ### 5.2.3 Evidential Inference Queries

# %% [markdown]
# <p id="app_studytime_given_G3"></p>
#
# * **What is a student's <u>studytime</u> given his <u>final grade</u>?**
#
# $$
# \begin{align}
# P(studytime| G3="Suficiente")
# \end{align}
# $$
#
# PDF (based on Exact Inference):
# - studytime(1): 0.3227
# - studytime(2): 0.4785
# - studytime(3):  0.1387
# - studytime(4): 0.0601
#
#
# <a href = "#index_app"><u>*back to the index of inferences*</u></a>

# %%
#variables:
query_variable = 'studytime'
evidence_variables = dict({"G3": "Suficiente"})

#Approximate inference:
for i in samples_num:
    q = approx_infer.query([query_variable], 
                            i, 
                            evidence_variables,
                           show_progress = False)
    
    print(f'Conditional Probability Table of variable "{query_variable}" given that "{evidence_variables}" are observed:')
    print(f'\nNumber of samples used to compute the approximate inference:\t{i}')
    print(f'\nConditional Probability Table:\n{q}')
# Out:
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	44
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.2045 |
# +--------------+------------------+
# | studytime(2) |           0.4773 |
# +--------------+------------------+
# | studytime(3) |           0.2500 |
# +--------------+------------------+
# | studytime(4) |           0.0682 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	144
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3750 |
# +--------------+------------------+
# | studytime(2) |           0.4167 |
# +--------------+------------------+
# | studytime(3) |           0.1528 |
# +--------------+------------------+
# | studytime(4) |           0.0556 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	244
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3607 |
# +--------------+------------------+
# | studytime(2) |           0.4344 |
# +--------------+------------------+
# | studytime(3) |           0.1270 |
# +--------------+------------------+
# | studytime(4) |           0.0779 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	344
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.2878 |
# +--------------+------------------+
# | studytime(2) |           0.4884 |
# +--------------+------------------+
# | studytime(3) |           0.1715 |
# +--------------+------------------+
# | studytime(4) |           0.0523 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	444
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3131 |
# +--------------+------------------+
# | studytime(2) |           0.4955 |
# +--------------+------------------+
# | studytime(3) |           0.1329 |
# +--------------+------------------+
# | studytime(4) |           0.0586 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	544
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3364 |
# +--------------+------------------+
# | studytime(2) |           0.4430 |
# +--------------+------------------+
# | studytime(3) |           0.1673 |
# +--------------+------------------+
# | studytime(4) |           0.0533 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	644
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3540 |
# +--------------+------------------+
# | studytime(2) |           0.4581 |
# +--------------+------------------+
# | studytime(3) |           0.1289 |
# +--------------+------------------+
# | studytime(4) |           0.0590 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	744
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3374 |
# +--------------+------------------+
# | studytime(2) |           0.4906 |
# +--------------+------------------+
# | studytime(3) |           0.1290 |
# +--------------+------------------+
# | studytime(4) |           0.0430 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	844
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3140 |
# +--------------+------------------+
# | studytime(2) |           0.4692 |
# +--------------+------------------+
# | studytime(3) |           0.1493 |
# +--------------+------------------+
# | studytime(4) |           0.0675 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	944
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3167 |
# +--------------+------------------+
# | studytime(2) |           0.4555 |
# +--------------+------------------+
# | studytime(3) |           0.1515 |
# +--------------+------------------+
# | studytime(4) |           0.0763 |
# +--------------+------------------+
# Conditional Probability Table of variable "studytime" given that "{'G3': 'Suficiente'}" are observed:
#
# Number of samples used to compute the approximate inference:	1044
#
# Conditional Probability Table:
# +--------------+------------------+
# | studytime    |   phi(studytime) |
# +==============+==================+
# | studytime(1) |           0.3257 |
# +--------------+------------------+
# | studytime(2) |           0.4492 |
# +--------------+------------------+
# | studytime(3) |           0.1609 |
# +--------------+------------------+
# | studytime(4) |           0.0642 |
# +--------------+------------------+

# %% [markdown]
# ## 6. Conclusions
#
# <p id="conclusions"></p>
#
#
# What can be inferred from our Bayesian model is that the feature that most affects a student's grade (`G3`) is the amount of `studytime`. However, as we can see in <a href="#G3_given_studytime_activities"><u>*this query*</u></a>, if the value of `studytime` is intermediate, but the students participate to extracurricular `activities`, then the grades below 'sufficient' have lower probabilities and inversively the grades above 'sufficient' have higher probabilities, all w.r.t. the case of high value of `studytime`.
#
# Another noteworthy consideration involves the student's alcohol consumption that, as we can see in <a href = "#G3_given_dalc"><u>*this query*</u></a>, doesn't really influence the final grade. Unexpectedly though, in <a href="dalc_given_studytime_goout"><u>*this other query*</u></a> we observe that there still are high levels of `Dalc`, even for students that study a lot. <br>In conclusion, we can say that drinking to much alcohol doesn't really affect the final grade. Although studying too much corresponds to the risk of higher consumption of alcohol due to mental health issues, or at list this is what we would like to think.
#
#
# <a href = "#index"><b>*back to the top*</b></a>

# %% [markdown]
# ## 7. Bibliography
#
# <p id="bibliography"></p>
#
# - https://degree.lamar.edu/articles/undergraduate/parents-education-level-and-childrens-success/
# - https://www.brookings.edu/blog/up-front/2021/01/12/the-unreported-gender-gap-in-high-school-graduation-rates/
# - https://hbr.org/2018/06/how-working-parents-can-manage-the-demands-of-school-age-kids
# - https://www.scholaro.com/db/Countries/Portugal/Grading-System
